# %%
# -*- coding: utf-8 -*-
import warnings
warnings.filterwarnings('ignore')
import logging
import datetime

import csv, math
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.utils import shuffle
from sklearn.externals import joblib
from sklearn.preprocessing import OneHotEncoder
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import GradientBoostingRegressor

from dayu.hooks.oss_hook import OSSHook
from dayu.hooks.hive_server_hook import HiveServerHook
from dayu.hooks.hive_cli_hook import HiveCliHook

def split_table_name(datain):
    new_cols = []
    for column in datain.columns:
        if(len(column.split('.'))<2):
            return datain
        tb_name, col_name = column.split('.')
        new_cols.append((column, col_name))
    datain = datain.rename(columns=dict(new_cols))
    return datain

def read_from_hive2(output_file_name,insql,dtype):
    filename = output_file_name
    filepath = curr_dir+filename
    hive = HiveServerHook("warehouse_hive")
    hive.to_csv(insql,filepath , delimiter=',',lineterminator='\n', output_header=True)
    outdata = pd.read_csv(filepath, header=0,dtype=dtype)
    # 去除列名中带有的表名
#     outdata = split_table_name(outdata)
    return outdata

## 计算时间差
def date_time_sub(startTime,endTime,date_format):
    try:
        startTime= datetime.datetime.strptime(startTime,date_format)
        endTime= datetime.datetime.strptime(endTime,date_format)
        return (endTime - startTime).days
    except:
        pass

    # 计算车辆当前保值率
def computer_with_license_month(tar):
    try:
        license_month = tar['license_month']
        if(license_month<=12):
            #tar['keep_value'] = tar['year_1']
            return tar['year_1']
        else:
            year = license_month//12
            #当前年保值率
            keep_max = tar["year_"+str(int(year))]
            #下一年的保值率
            keep_min = tar["year_"+str(int(year+1))]

            #相比于上一年，已经过了几个月
            mon = license_month-12*year
            tem = (keep_max-keep_min)/12

            #tar['keep_value'] = round(keep_max - tem*mon, 4)
            return round(keep_max - tem*mon, 4)
    except:
        return tar["year_16"]

class Logger:       
    def __init__(self, logName, logFile):
        self._logger = logging.getLogger(logName)
        handler = logging.FileHandler(logFile)
        formatter = logging.Formatter('%(asctime)s ********* %(message)s')
        handler.setFormatter(formatter)
        self._logger.addHandler(handler)
        self._logger.setLevel(logging.INFO)

    def log(self, msg):
        if self._logger is not None:
            self._logger.info(msg)


pd.set_option('display.max_columns', 500)
curr_dir = '/home/souche/qiongjiu/hgc/'

curr_date=str(datetime.datetime.now())[0:10]
hive_cli = HiveCliHook("warehouse_hive")

logger = Logger('model_service','./log/accurate_valuation_cyp_run_log.log')
logger.log("程序启动.............")
## 设定需要计算的年
computer_year = '2019'
# Out:
# DAYU_HOME : /home/souche/projects/datacenter-etl-v2
# [2021-02-04 15:46:56,170] {driver:120} INFO - Generating grammar tables from /usr/lib/python3.5/lib2to3/Grammar.txt
# [2021-02-04 15:46:56,197] {driver:120} INFO - Generating grammar tables from /usr/lib/python3.5/lib2to3/PatternGrammar.txt
# [2021-02-04 15:46:56,541] {<ipython-input-1-bac83ce33734>:84} INFO - 程序启动.............

# %%
sql_info ="""
select * 
from (
    SELECT
        car_id,
        brand_name,
        model_name,
        a_province_name,
        model_code,
        substr(publish_time,1,4)  pay_year,
        substr(license_time,1,4) license_year,
        second_price/10000 real_pay_amount,
        a_province_name,
        mileage,
        row_number() over(partition by model_code,mileage,license_time,a_province_name order by publish_time desc) num 
    FROM
        dl_outrs.dl_vehicle_data_scavenger_ipbl_t_reptile_car_dd
    WHERE
        ds = date_sub('"""+curr_date+"""',1) 
        and second_price/10000 >= 0.3    
        and second_price/10000 < 300 
        and mileage/10000 > 0     
        and mileage/10000 < 100 
        and site not in ('51','renrenche') 
        and substr(publish_time,0,4) in ('"""+computer_year+"""')
) t1
where t1.num = 1 
"""
dtype={'city_code':str}
dl_site_ts_order_clean = read_from_hive2('dl_site_ts_order_clean',sql_info,dtype)

db_columns = []
for col in dl_site_ts_order_clean.columns:
    if len(col.split('.')) > 1:
        db_columns.append(col.split('.')[1])

    else:
        db_columns.append(col)

dl_site_ts_order_clean.columns = db_columns 
logger.log("读取数据完成.............")
# Out:
# [2021-01-07 15:20:27,585] {hiveserver2:138} INFO - Using database default as default
# [2021-01-07 15:20:27,725] {hive_server_hook:112} INFO - Running query:
# select *
# from (
#     SELECT
#         car_id,
#         brand_name,
#         model_name,
#         a_province_name,
#         model_code,
#         substr(publish_time,1,4)  pay_year,
#         substr(license_time,1,4) license_year,
#         second_price/10000 real_pay_amount,
#         a_province_name,
#         mileage,
#         row_number() over(partition by model_code,mileage,license_time,a_province_name order by publish_time desc) num
#     FROM
#         dl_outrs.dl_vehicle_data_scavenger_ipbl_t_reptile_car_dd
#     WHERE
#         ds = date_sub('2021-01-07',1)
#         and second_price/10000 >= 0.3
#         and second_price/10000 < 300
#         and mileage/10000 > 0
#         and mileage/10000 < 100
#         and site not in ('51','renrenche')
#         and substr(publish_time,0,4) in ('2019')
# ) t1
# where t1.num = 1
#
# [2021-01-07 15:21:33,337] {hive_server_hook:162} INFO - Written 10000 rows so far.
# [2021-01-07 15:21:33,770] {hive_server_hook:162} INFO - Written 20000 rows so far.
# [2021-01-07 15:21:34,203] {hive_server_hook:162} INFO - Written 30000 rows so far.
# [2021-01-07 15:21:34,633] {hive_server_hook:162} INFO - Written 40000 rows so far.
# [2021-01-07 15:21:35,044] {hive_server_hook:162} INFO - Written 50000 rows so far.
# [2021-01-07 15:21:35,485] {hive_server_hook:162} INFO - Written 60000 rows so far.
# [2021-01-07 15:21:35,918] {hive_server_hook:162} INFO - Written 70000 rows so far.
# [2021-01-07 15:21:36,371] {hive_server_hook:162} INFO - Written 80000 rows so far.
# [2021-01-07 15:21:36,776] {hive_server_hook:162} INFO - Written 90000 rows so far.
# [2021-01-07 15:21:37,206] {hive_server_hook:162} INFO - Written 100000 rows so far.
# [2021-01-07 15:21:37,639] {hive_server_hook:162} INFO - Written 110000 rows so far.
# [2021-01-07 15:21:38,067] {hive_server_hook:162} INFO - Written 120000 rows so far.
# [2021-01-07 15:21:38,471] {hive_server_hook:162} INFO - Written 130000 rows so far.
# [2021-01-07 15:21:38,906] {hive_server_hook:162} INFO - Written 140000 rows so far.
# [2021-01-07 15:21:39,333] {hive_server_hook:162} INFO - Written 150000 rows so far.
# [2021-01-07 15:21:39,756] {hive_server_hook:162} INFO - Written 160000 rows so far.
# [2021-01-07 15:21:40,197] {hive_server_hook:162} INFO - Written 170000 rows so far.
# [2021-01-07 15:21:40,603] {hive_server_hook:162} INFO - Written 180000 rows so far.
# [2021-01-07 15:21:41,027] {hive_server_hook:162} INFO - Written 190000 rows so far.
# [2021-01-07 15:21:41,450] {hive_server_hook:162} INFO - Written 200000 rows so far.
# [2021-01-07 15:21:41,870] {hive_server_hook:162} INFO - Written 210000 rows so far.
# [2021-01-07 15:21:42,261] {hive_server_hook:162} INFO - Written 220000 rows so far.
# [2021-01-07 15:21:42,681] {hive_server_hook:162} INFO - Written 230000 rows so far.
# [2021-01-07 15:21:43,102] {hive_server_hook:162} INFO - Written 240000 rows so far.
# [2021-01-07 15:21:43,522] {hive_server_hook:162} INFO - Written 250000 rows so far.
# [2021-01-07 15:21:43,918] {hive_server_hook:162} INFO - Written 260000 rows so far.
# [2021-01-07 15:21:44,339] {hive_server_hook:162} INFO - Written 270000 rows so far.
# [2021-01-07 15:21:44,760] {hive_server_hook:162} INFO - Written 280000 rows so far.
# [2021-01-07 15:21:45,186] {hive_server_hook:162} INFO - Written 290000 rows so far.
# [2021-01-07 15:21:45,581] {hive_server_hook:162} INFO - Written 300000 rows so far.
# [2021-01-07 15:21:46,002] {hive_server_hook:162} INFO - Written 310000 rows so far.
# [2021-01-07 15:21:46,425] {hive_server_hook:162} INFO - Written 320000 rows so far.
# [2021-01-07 15:21:46,844] {hive_server_hook:162} INFO - Written 330000 rows so far.
# [2021-01-07 15:21:47,265] {hive_server_hook:162} INFO - Written 340000 rows so far.
# [2021-01-07 15:21:47,660] {hive_server_hook:162} INFO - Written 350000 rows so far.
# [2021-01-07 15:21:48,091] {hive_server_hook:162} INFO - Written 360000 rows so far.
# [2021-01-07 15:21:48,512] {hive_server_hook:162} INFO - Written 370000 rows so far.
# [2021-01-07 15:21:48,931] {hive_server_hook:162} INFO - Written 380000 rows so far.
# [2021-01-07 15:21:49,323] {hive_server_hook:162} INFO - Written 390000 rows so far.
# [2021-01-07 15:21:49,743] {hive_server_hook:162} INFO - Written 400000 rows so far.
# [2021-01-07 15:21:50,168] {hive_server_hook:162} INFO - Written 410000 rows so far.
# [2021-01-07 15:21:50,598] {hive_server_hook:162} INFO - Written 420000 rows so far.
# [2021-01-07 15:21:50,996] {hive_server_hook:162} INFO - Written 430000 rows so far.
# [2021-01-07 15:21:51,423] {hive_server_hook:162} INFO - Written 440000 rows so far.
# [2021-01-07 15:21:51,925] {hive_server_hook:162} INFO - Written 450000 rows so far.
# [2021-01-07 15:21:52,345] {hive_server_hook:162} INFO - Written 460000 rows so far.
# [2021-01-07 15:21:52,734] {hive_server_hook:162} INFO - Written 470000 rows so far.
# [2021-01-07 15:21:53,151] {hive_server_hook:162} INFO - Written 480000 rows so far.
# [2021-01-07 15:21:53,571] {hive_server_hook:162} INFO - Written 490000 rows so far.
# [2021-01-07 15:21:53,990] {hive_server_hook:162} INFO - Written 500000 rows so far.
# [2021-01-07 15:21:54,413] {hive_server_hook:162} INFO - Written 510000 rows so far.
# [2021-01-07 15:21:54,807] {hive_server_hook:162} INFO - Written 520000 rows so far.
# [2021-01-07 15:21:55,232] {hive_server_hook:162} INFO - Written 530000 rows so far.
# [2021-01-07 15:21:55,653] {hive_server_hook:162} INFO - Written 540000 rows so far.
# [2021-01-07 15:21:56,076] {hive_server_hook:162} INFO - Written 550000 rows so far.
# [2021-01-07 15:21:56,469] {hive_server_hook:162} INFO - Written 560000 rows so far.
# [2021-01-07 15:21:56,886] {hive_server_hook:162} INFO - Written 570000 rows so far.
# [2021-01-07 15:21:57,305] {hive_server_hook:162} INFO - Written 580000 rows so far.
# [2021-01-07 15:21:57,734] {hive_server_hook:162} INFO - Written 590000 rows so far.
# [2021-01-07 15:21:58,141] {hive_server_hook:162} INFO - Written 600000 rows so far.
# [2021-01-07 15:21:58,565] {hive_server_hook:162} INFO - Written 610000 rows so far.
# [2021-01-07 15:21:58,987] {hive_server_hook:162} INFO - Written 620000 rows so far.
# [2021-01-07 15:21:59,404] {hive_server_hook:162} INFO - Written 630000 rows so far.
# [2021-01-07 15:21:59,794] {hive_server_hook:162} INFO - Written 640000 rows so far.
# [2021-01-07 15:22:00,226] {hive_server_hook:162} INFO - Written 650000 rows so far.
# [2021-01-07 15:22:00,656] {hive_server_hook:162} INFO - Written 660000 rows so far.
# [2021-01-07 15:22:01,079] {hive_server_hook:162} INFO - Written 670000 rows so far.
# [2021-01-07 15:22:01,500] {hive_server_hook:162} INFO - Written 680000 rows so far.
# [2021-01-07 15:22:01,893] {hive_server_hook:162} INFO - Written 690000 rows so far.
# [2021-01-07 15:22:02,314] {hive_server_hook:162} INFO - Written 700000 rows so far.
# [2021-01-07 15:22:02,734] {hive_server_hook:162} INFO - Written 710000 rows so far.
# [2021-01-07 15:22:03,152] {hive_server_hook:162} INFO - Written 720000 rows so far.
# [2021-01-07 15:22:03,543] {hive_server_hook:162} INFO - Written 730000 rows so far.
# [2021-01-07 15:22:03,963] {hive_server_hook:162} INFO - Written 740000 rows so far.
# [2021-01-07 15:22:04,387] {hive_server_hook:162} INFO - Written 750000 rows so far.
# [2021-01-07 15:22:04,807] {hive_server_hook:162} INFO - Written 760000 rows so far.
# [2021-01-07 15:22:05,196] {hive_server_hook:162} INFO - Written 770000 rows so far.
# [2021-01-07 15:22:05,647] {hive_server_hook:162} INFO - Written 780000 rows so far.
# [2021-01-07 15:22:06,072] {hive_server_hook:162} INFO - Written 790000 rows so far.
# [2021-01-07 15:22:06,493] {hive_server_hook:162} INFO - Written 800000 rows so far.
# [2021-01-07 15:22:06,930] {hive_server_hook:162} INFO - Written 810000 rows so far.
# [2021-01-07 15:22:07,329] {hive_server_hook:162} INFO - Written 820000 rows so far.
# [2021-01-07 15:22:07,750] {hive_server_hook:162} INFO - Written 830000 rows so far.
# [2021-01-07 15:22:08,171] {hive_server_hook:162} INFO - Written 840000 rows so far.
# [2021-01-07 15:22:08,591] {hive_server_hook:162} INFO - Written 850000 rows so far.
# [2021-01-07 15:22:08,987] {hive_server_hook:162} INFO - Written 860000 rows so far.
# [2021-01-07 15:22:09,409] {hive_server_hook:162} INFO - Written 870000 rows so far.
# [2021-01-07 15:22:09,833] {hive_server_hook:162} INFO - Written 880000 rows so far.
# [2021-01-07 15:22:10,265] {hive_server_hook:162} INFO - Written 890000 rows so far.
# [2021-01-07 15:22:10,669] {hive_server_hook:162} INFO - Written 900000 rows so far.
# [2021-01-07 15:22:11,093] {hive_server_hook:162} INFO - Written 910000 rows so far.
# [2021-01-07 15:22:11,518] {hive_server_hook:162} INFO - Written 920000 rows so far.
# [2021-01-07 15:22:11,942] {hive_server_hook:162} INFO - Written 930000 rows so far.
# [2021-01-07 15:22:12,338] {hive_server_hook:162} INFO - Written 940000 rows so far.
# [2021-01-07 15:22:12,757] {hive_server_hook:162} INFO - Written 950000 rows so far.
# [2021-01-07 15:22:13,182] {hive_server_hook:162} INFO - Written 960000 rows so far.
# [2021-01-07 15:22:13,615] {hive_server_hook:162} INFO - Written 970000 rows so far.
# [2021-01-07 15:22:14,048] {hive_server_hook:162} INFO - Written 980000 rows so far.
# [2021-01-07 15:22:14,455] {hive_server_hook:162} INFO - Written 990000 rows so far.
# [2021-01-07 15:22:14,888] {hive_server_hook:162} INFO - Written 1000000 rows so far.
# [2021-01-07 15:22:15,323] {hive_server_hook:162} INFO - Written 1010000 rows so far.
# [2021-01-07 15:22:15,756] {hive_server_hook:162} INFO - Written 1020000 rows so far.
# [2021-01-07 15:22:16,161] {hive_server_hook:162} INFO - Written 1030000 rows so far.
# [2021-01-07 15:22:16,598] {hive_server_hook:162} INFO - Written 1040000 rows so far.
# [2021-01-07 15:22:17,024] {hive_server_hook:162} INFO - Written 1050000 rows so far.
# [2021-01-07 15:22:17,444] {hive_server_hook:162} INFO - Written 1060000 rows so far.
# [2021-01-07 15:22:17,843] {hive_server_hook:162} INFO - Written 1070000 rows so far.
# [2021-01-07 15:22:18,263] {hive_server_hook:162} INFO - Written 1080000 rows so far.
# [2021-01-07 15:22:18,694] {hive_server_hook:162} INFO - Written 1090000 rows so far.
# [2021-01-07 15:22:19,132] {hive_server_hook:162} INFO - Written 1100000 rows so far.
# [2021-01-07 15:22:19,539] {hive_server_hook:162} INFO - Written 1110000 rows so far.
# [2021-01-07 15:22:19,978] {hive_server_hook:162} INFO - Written 1120000 rows so far.
# [2021-01-07 15:22:20,417] {hive_server_hook:162} INFO - Written 1130000 rows so far.
# [2021-01-07 15:22:20,852] {hive_server_hook:162} INFO - Written 1140000 rows so far.
# [2021-01-07 15:22:21,289] {hive_server_hook:162} INFO - Written 1150000 rows so far.
# [2021-01-07 15:22:21,699] {hive_server_hook:162} INFO - Written 1160000 rows so far.
# [2021-01-07 15:22:22,137] {hive_server_hook:162} INFO - Written 1170000 rows so far.
# [2021-01-07 15:22:22,573] {hive_server_hook:162} INFO - Written 1180000 rows so far.
# [2021-01-07 15:22:23,010] {hive_server_hook:162} INFO - Written 1190000 rows so far.
# [2021-01-07 15:22:23,416] {hive_server_hook:162} INFO - Written 1200000 rows so far.
# [2021-01-07 15:22:23,850] {hive_server_hook:162} INFO - Written 1210000 rows so far.
# [2021-01-07 15:22:24,286] {hive_server_hook:162} INFO - Written 1220000 rows so far.
# [2021-01-07 15:22:24,727] {hive_server_hook:162} INFO - Written 1230000 rows so far.
# [2021-01-07 15:22:25,134] {hive_server_hook:162} INFO - Written 1240000 rows so far.
# [2021-01-07 15:22:25,569] {hive_server_hook:162} INFO - Written 1250000 rows so far.
# [2021-01-07 15:22:26,005] {hive_server_hook:162} INFO - Written 1260000 rows so far.
# [2021-01-07 15:22:26,440] {hive_server_hook:162} INFO - Written 1270000 rows so far.
# [2021-01-07 15:22:26,847] {hive_server_hook:162} INFO - Written 1280000 rows so far.
# [2021-01-07 15:22:27,279] {hive_server_hook:162} INFO - Written 1290000 rows so far.
# [2021-01-07 15:22:27,714] {hive_server_hook:162} INFO - Written 1300000 rows so far.
# [2021-01-07 15:22:28,148] {hive_server_hook:162} INFO - Written 1310000 rows so far.
# [2021-01-07 15:22:28,585] {hive_server_hook:162} INFO - Written 1320000 rows so far.
# [2021-01-07 15:22:28,993] {hive_server_hook:162} INFO - Written 1330000 rows so far.
# [2021-01-07 15:22:29,428] {hive_server_hook:162} INFO - Written 1340000 rows so far.
# [2021-01-07 15:22:29,863] {hive_server_hook:162} INFO - Written 1350000 rows so far.
# [2021-01-07 15:22:30,300] {hive_server_hook:162} INFO - Written 1360000 rows so far.
# [2021-01-07 15:22:30,705] {hive_server_hook:162} INFO - Written 1370000 rows so far.
# [2021-01-07 15:22:31,129] {hive_server_hook:162} INFO - Written 1380000 rows so far.
# [2021-01-07 15:22:31,551] {hive_server_hook:162} INFO - Written 1390000 rows so far.
# [2021-01-07 15:22:31,976] {hive_server_hook:162} INFO - Written 1400000 rows so far.
# [2021-01-07 15:22:32,385] {hive_server_hook:162} INFO - Written 1410000 rows so far.
# [2021-01-07 15:22:32,819] {hive_server_hook:162} INFO - Written 1420000 rows so far.
# [2021-01-07 15:22:33,244] {hive_server_hook:162} INFO - Written 1430000 rows so far.
# [2021-01-07 15:22:33,677] {hive_server_hook:162} INFO - Written 1440000 rows so far.
# [2021-01-07 15:22:34,107] {hive_server_hook:162} INFO - Written 1450000 rows so far.
# [2021-01-07 15:22:34,511] {hive_server_hook:162} INFO - Written 1460000 rows so far.
# [2021-01-07 15:22:34,945] {hive_server_hook:162} INFO - Written 1470000 rows so far.
# [2021-01-07 15:22:35,381] {hive_server_hook:162} INFO - Written 1480000 rows so far.
# [2021-01-07 15:22:35,817] {hive_server_hook:162} INFO - Written 1490000 rows so far.
# [2021-01-07 15:22:36,246] {hive_server_hook:162} INFO - Written 1500000 rows so far.
# [2021-01-07 15:22:36,675] {hive_server_hook:162} INFO - Written 1510000 rows so far.
# [2021-01-07 15:22:37,098] {hive_server_hook:162} INFO - Written 1520000 rows so far.
# [2021-01-07 15:22:37,519] {hive_server_hook:162} INFO - Written 1530000 rows so far.
# [2021-01-07 15:22:37,910] {hive_server_hook:162} INFO - Written 1540000 rows so far.
# [2021-01-07 15:22:38,332] {hive_server_hook:162} INFO - Written 1550000 rows so far.
# [2021-01-07 15:22:38,756] {hive_server_hook:162} INFO - Written 1560000 rows so far.
# [2021-01-07 15:22:39,188] {hive_server_hook:162} INFO - Written 1570000 rows so far.
# [2021-01-07 15:22:39,579] {hive_server_hook:162} INFO - Written 1580000 rows so far.
# [2021-01-07 15:22:40,001] {hive_server_hook:162} INFO - Written 1590000 rows so far.
# [2021-01-07 15:22:40,434] {hive_server_hook:162} INFO - Written 1600000 rows so far.
# [2021-01-07 15:22:40,863] {hive_server_hook:162} INFO - Written 1610000 rows so far.
# [2021-01-07 15:22:41,309] {hive_server_hook:162} INFO - Written 1620000 rows so far.
# [2021-01-07 15:22:41,721] {hive_server_hook:162} INFO - Written 1630000 rows so far.
# [2021-01-07 15:22:42,153] {hive_server_hook:162} INFO - Written 1640000 rows so far.
# [2021-01-07 15:22:42,581] {hive_server_hook:162} INFO - Written 1650000 rows so far.
# [2021-01-07 15:22:43,008] {hive_server_hook:162} INFO - Written 1660000 rows so far.
# [2021-01-07 15:22:43,403] {hive_server_hook:162} INFO - Written 1670000 rows so far.
# [2021-01-07 15:22:43,822] {hive_server_hook:162} INFO - Written 1680000 rows so far.
# [2021-01-07 15:22:44,239] {hive_server_hook:162} INFO - Written 1690000 rows so far.
# [2021-01-07 15:22:44,653] {hive_server_hook:162} INFO - Written 1700000 rows so far.
# [2021-01-07 15:22:45,038] {hive_server_hook:162} INFO - Written 1710000 rows so far.
# [2021-01-07 15:22:45,460] {hive_server_hook:162} INFO - Written 1720000 rows so far.
# [2021-01-07 15:22:45,891] {hive_server_hook:162} INFO - Written 1730000 rows so far.
# [2021-01-07 15:22:46,329] {hive_server_hook:162} INFO - Written 1740000 rows so far.
# [2021-01-07 15:22:46,723] {hive_server_hook:162} INFO - Written 1750000 rows so far.
# [2021-01-07 15:22:47,159] {hive_server_hook:162} INFO - Written 1760000 rows so far.
# [2021-01-07 15:22:47,590] {hive_server_hook:162} INFO - Written 1770000 rows so far.
# [2021-01-07 15:22:48,022] {hive_server_hook:162} INFO - Written 1780000 rows so far.
# [2021-01-07 15:22:48,458] {hive_server_hook:162} INFO - Written 1790000 rows so far.
# [2021-01-07 15:22:48,863] {hive_server_hook:162} INFO - Written 1800000 rows so far.
# [2021-01-07 15:22:49,288] {hive_server_hook:162} INFO - Written 1810000 rows so far.
# [2021-01-07 15:22:49,718] {hive_server_hook:162} INFO - Written 1820000 rows so far.
# [2021-01-07 15:22:50,151] {hive_server_hook:162} INFO - Written 1830000 rows so far.
# [2021-01-07 15:22:50,559] {hive_server_hook:162} INFO - Written 1840000 rows so far.
# [2021-01-07 15:22:50,998] {hive_server_hook:162} INFO - Written 1850000 rows so far.
# [2021-01-07 15:22:51,421] {hive_server_hook:162} INFO - Written 1860000 rows so far.
# [2021-01-07 15:22:51,908] {hive_server_hook:162} INFO - Written 1870000 rows so far.
# [2021-01-07 15:22:52,327] {hive_server_hook:162} INFO - Written 1880000 rows so far.
# [2021-01-07 15:22:52,764] {hive_server_hook:162} INFO - Written 1890000 rows so far.
# [2021-01-07 15:22:53,200] {hive_server_hook:162} INFO - Written 1900000 rows so far.
# [2021-01-07 15:22:53,648] {hive_server_hook:162} INFO - Written 1910000 rows so far.
# [2021-01-07 15:22:54,058] {hive_server_hook:162} INFO - Written 1920000 rows so far.
# [2021-01-07 15:22:54,491] {hive_server_hook:162} INFO - Written 1930000 rows so far.
# [2021-01-07 15:22:54,930] {hive_server_hook:162} INFO - Written 1940000 rows so far.
# [2021-01-07 15:22:55,368] {hive_server_hook:162} INFO - Written 1950000 rows so far.
# [2021-01-07 15:22:55,810] {hive_server_hook:162} INFO - Written 1960000 rows so far.
# [2021-01-07 15:22:56,226] {hive_server_hook:162} INFO - Written 1970000 rows so far.
# [2021-01-07 15:22:56,670] {hive_server_hook:162} INFO - Written 1980000 rows so far.
# [2021-01-07 15:22:57,119] {hive_server_hook:162} INFO - Written 1990000 rows so far.
# [2021-01-07 15:22:57,563] {hive_server_hook:162} INFO - Written 2000000 rows so far.
# [2021-01-07 15:22:57,981] {hive_server_hook:162} INFO - Written 2010000 rows so far.
# [2021-01-07 15:22:58,429] {hive_server_hook:162} INFO - Written 2020000 rows so far.
# [2021-01-07 15:22:58,875] {hive_server_hook:162} INFO - Written 2030000 rows so far.
# [2021-01-07 15:22:59,336] {hive_server_hook:162} INFO - Written 2040000 rows so far.
# [2021-01-07 15:22:59,735] {hive_server_hook:162} INFO - Written 2050000 rows so far.
# [2021-01-07 15:23:00,160] {hive_server_hook:162} INFO - Written 2060000 rows so far.
# [2021-01-07 15:23:00,608] {hive_server_hook:162} INFO - Written 2070000 rows so far.
# [2021-01-07 15:23:01,046] {hive_server_hook:162} INFO - Written 2080000 rows so far.
# [2021-01-07 15:23:01,484] {hive_server_hook:162} INFO - Written 2090000 rows so far.
# [2021-01-07 15:23:01,894] {hive_server_hook:162} INFO - Written 2100000 rows so far.
# [2021-01-07 15:23:02,328] {hive_server_hook:162} INFO - Written 2110000 rows so far.
# [2021-01-07 15:23:02,767] {hive_server_hook:162} INFO - Written 2120000 rows so far.
# [2021-01-07 15:23:03,248] {hive_server_hook:162} INFO - Written 2130000 rows so far.
# [2021-01-07 15:23:03,654] {hive_server_hook:162} INFO - Written 2140000 rows so far.
# [2021-01-07 15:23:04,089] {hive_server_hook:162} INFO - Written 2150000 rows so far.
# [2021-01-07 15:23:04,523] {hive_server_hook:162} INFO - Written 2160000 rows so far.
# [2021-01-07 15:23:04,955] {hive_server_hook:162} INFO - Written 2170000 rows so far.
# [2021-01-07 15:23:05,363] {hive_server_hook:162} INFO - Written 2180000 rows so far.
# [2021-01-07 15:23:05,799] {hive_server_hook:162} INFO - Written 2190000 rows so far.
# [2021-01-07 15:23:06,234] {hive_server_hook:162} INFO - Written 2200000 rows so far.
# [2021-01-07 15:23:06,667] {hive_server_hook:162} INFO - Written 2210000 rows so far.
# [2021-01-07 15:23:07,071] {hive_server_hook:162} INFO - Written 2220000 rows so far.
# [2021-01-07 15:23:07,502] {hive_server_hook:162} INFO - Written 2230000 rows so far.
# [2021-01-07 15:23:07,941] {hive_server_hook:162} INFO - Written 2240000 rows so far.
# [2021-01-07 15:23:08,372] {hive_server_hook:162} INFO - Written 2250000 rows so far.
# [2021-01-07 15:23:08,807] {hive_server_hook:162} INFO - Written 2260000 rows so far.
# [2021-01-07 15:23:09,208] {hive_server_hook:162} INFO - Written 2270000 rows so far.
# [2021-01-07 15:23:09,640] {hive_server_hook:162} INFO - Written 2280000 rows so far.
# [2021-01-07 15:23:10,078] {hive_server_hook:162} INFO - Written 2290000 rows so far.
# [2021-01-07 15:23:10,520] {hive_server_hook:162} INFO - Written 2300000 rows so far.
# [2021-01-07 15:23:10,923] {hive_server_hook:162} INFO - Written 2310000 rows so far.
# [2021-01-07 15:23:11,355] {hive_server_hook:162} INFO - Written 2320000 rows so far.
# [2021-01-07 15:23:11,791] {hive_server_hook:162} INFO - Written 2330000 rows so far.
# [2021-01-07 15:23:12,224] {hive_server_hook:162} INFO - Written 2340000 rows so far.
# [2021-01-07 15:23:12,627] {hive_server_hook:162} INFO - Written 2350000 rows so far.
# [2021-01-07 15:23:13,059] {hive_server_hook:162} INFO - Written 2360000 rows so far.
# [2021-01-07 15:23:13,493] {hive_server_hook:162} INFO - Written 2370000 rows so far.
# [2021-01-07 15:23:13,925] {hive_server_hook:162} INFO - Written 2380000 rows so far.
# [2021-01-07 15:23:14,331] {hive_server_hook:162} INFO - Written 2390000 rows so far.
# [2021-01-07 15:23:14,767] {hive_server_hook:162} INFO - Written 2400000 rows so far.
# [2021-01-07 15:23:15,208] {hive_server_hook:162} INFO - Written 2410000 rows so far.
# [2021-01-07 15:23:15,650] {hive_server_hook:162} INFO - Written 2420000 rows so far.
# [2021-01-07 15:23:16,090] {hive_server_hook:162} INFO - Written 2430000 rows so far.
# [2021-01-07 15:23:16,501] {hive_server_hook:162} INFO - Written 2440000 rows so far.
# [2021-01-07 15:23:16,941] {hive_server_hook:162} INFO - Written 2450000 rows so far.
# [2021-01-07 15:23:17,383] {hive_server_hook:162} INFO - Written 2460000 rows so far.
# [2021-01-07 15:23:17,821] {hive_server_hook:162} INFO - Written 2470000 rows so far.
# [2021-01-07 15:23:18,230] {hive_server_hook:162} INFO - Written 2480000 rows so far.
# [2021-01-07 15:23:18,655] {hive_server_hook:162} INFO - Written 2490000 rows so far.
# [2021-01-07 15:23:19,082] {hive_server_hook:162} INFO - Written 2500000 rows so far.
# [2021-01-07 15:23:19,517] {hive_server_hook:162} INFO - Written 2510000 rows so far.
# [2021-01-07 15:23:19,925] {hive_server_hook:162} INFO - Written 2520000 rows so far.
# [2021-01-07 15:23:20,366] {hive_server_hook:162} INFO - Written 2530000 rows so far.
# [2021-01-07 15:23:20,807] {hive_server_hook:162} INFO - Written 2540000 rows so far.
# [2021-01-07 15:23:21,249] {hive_server_hook:162} INFO - Written 2550000 rows so far.
# [2021-01-07 15:23:21,663] {hive_server_hook:162} INFO - Written 2560000 rows so far.
# [2021-01-07 15:23:22,100] {hive_server_hook:162} INFO - Written 2570000 rows so far.
# [2021-01-07 15:23:22,538] {hive_server_hook:162} INFO - Written 2580000 rows so far.
# [2021-01-07 15:23:22,972] {hive_server_hook:162} INFO - Written 2590000 rows so far.
# [2021-01-07 15:23:23,393] {hive_server_hook:162} INFO - Written 2600000 rows so far.
# [2021-01-07 15:23:23,787] {hive_server_hook:162} INFO - Written 2610000 rows so far.
# [2021-01-07 15:23:24,210] {hive_server_hook:162} INFO - Written 2620000 rows so far.
# [2021-01-07 15:23:24,630] {hive_server_hook:162} INFO - Written 2630000 rows so far.
# [2021-01-07 15:23:25,068] {hive_server_hook:162} INFO - Written 2640000 rows so far.
# [2021-01-07 15:23:25,471] {hive_server_hook:162} INFO - Written 2650000 rows so far.
# [2021-01-07 15:23:25,908] {hive_server_hook:162} INFO - Written 2660000 rows so far.
# [2021-01-07 15:23:26,344] {hive_server_hook:162} INFO - Written 2670000 rows so far.
# [2021-01-07 15:23:26,782] {hive_server_hook:162} INFO - Written 2680000 rows so far.
# [2021-01-07 15:23:27,193] {hive_server_hook:162} INFO - Written 2690000 rows so far.
# [2021-01-07 15:23:27,632] {hive_server_hook:162} INFO - Written 2700000 rows so far.
# [2021-01-07 15:23:28,070] {hive_server_hook:162} INFO - Written 2710000 rows so far.
# [2021-01-07 15:23:28,510] {hive_server_hook:162} INFO - Written 2720000 rows so far.
# [2021-01-07 15:23:28,951] {hive_server_hook:162} INFO - Written 2730000 rows so far.
# [2021-01-07 15:23:29,361] {hive_server_hook:162} INFO - Written 2740000 rows so far.
# [2021-01-07 15:23:29,810] {hive_server_hook:162} INFO - Written 2750000 rows so far.
# [2021-01-07 15:23:30,251] {hive_server_hook:162} INFO - Written 2760000 rows so far.
# [2021-01-07 15:23:30,693] {hive_server_hook:162} INFO - Written 2770000 rows so far.
# [2021-01-07 15:23:31,105] {hive_server_hook:162} INFO - Written 2780000 rows so far.
# [2021-01-07 15:23:31,535] {hive_server_hook:162} INFO - Written 2790000 rows so far.
# [2021-01-07 15:23:31,972] {hive_server_hook:162} INFO - Written 2800000 rows so far.
# [2021-01-07 15:23:32,410] {hive_server_hook:162} INFO - Written 2810000 rows so far.
# [2021-01-07 15:23:32,821] {hive_server_hook:162} INFO - Written 2820000 rows so far.
# [2021-01-07 15:23:33,258] {hive_server_hook:162} INFO - Written 2830000 rows so far.
# [2021-01-07 15:23:33,693] {hive_server_hook:162} INFO - Written 2840000 rows so far.
# [2021-01-07 15:23:34,131] {hive_server_hook:162} INFO - Written 2850000 rows so far.
# [2021-01-07 15:23:34,538] {hive_server_hook:162} INFO - Written 2860000 rows so far.
# [2021-01-07 15:23:34,975] {hive_server_hook:162} INFO - Written 2870000 rows so far.
# [2021-01-07 15:23:35,410] {hive_server_hook:162} INFO - Written 2880000 rows so far.
# [2021-01-07 15:23:35,844] {hive_server_hook:162} INFO - Written 2890000 rows so far.
# [2021-01-07 15:23:36,292] {hive_server_hook:162} INFO - Written 2900000 rows so far.
# [2021-01-07 15:23:36,698] {hive_server_hook:162} INFO - Written 2910000 rows so far.
# [2021-01-07 15:23:37,146] {hive_server_hook:162} INFO - Written 2920000 rows so far.
# [2021-01-07 15:23:37,581] {hive_server_hook:162} INFO - Written 2930000 rows so far.
# [2021-01-07 15:23:38,011] {hive_server_hook:162} INFO - Written 2940000 rows so far.
# [2021-01-07 15:23:38,404] {hive_server_hook:162} INFO - Written 2950000 rows so far.
# [2021-01-07 15:23:38,824] {hive_server_hook:162} INFO - Written 2960000 rows so far.
# [2021-01-07 15:23:39,240] {hive_server_hook:162} INFO - Written 2970000 rows so far.
# [2021-01-07 15:23:39,657] {hive_server_hook:162} INFO - Written 2980000 rows so far.
# [2021-01-07 15:23:40,059] {hive_server_hook:162} INFO - Written 2990000 rows so far.
# [2021-01-07 15:23:40,485] {hive_server_hook:162} INFO - Written 3000000 rows so far.
# [2021-01-07 15:23:40,902] {hive_server_hook:162} INFO - Written 3010000 rows so far.
# [2021-01-07 15:23:41,322] {hive_server_hook:162} INFO - Written 3020000 rows so far.
# [2021-01-07 15:23:41,717] {hive_server_hook:162} INFO - Written 3030000 rows so far.
# [2021-01-07 15:23:42,138] {hive_server_hook:162} INFO - Written 3040000 rows so far.
# [2021-01-07 15:23:42,556] {hive_server_hook:162} INFO - Written 3050000 rows so far.
# [2021-01-07 15:23:42,974] {hive_server_hook:162} INFO - Written 3060000 rows so far.
# [2021-01-07 15:23:43,391] {hive_server_hook:162} INFO - Written 3070000 rows so far.
# [2021-01-07 15:23:43,785] {hive_server_hook:162} INFO - Written 3080000 rows so far.
# [2021-01-07 15:23:44,208] {hive_server_hook:162} INFO - Written 3090000 rows so far.
# [2021-01-07 15:23:44,636] {hive_server_hook:162} INFO - Written 3100000 rows so far.
# [2021-01-07 15:23:45,067] {hive_server_hook:162} INFO - Written 3110000 rows so far.
# [2021-01-07 15:23:45,468] {hive_server_hook:162} INFO - Written 3120000 rows so far.
# [2021-01-07 15:23:45,883] {hive_server_hook:162} INFO - Written 3130000 rows so far.
# [2021-01-07 15:23:46,298] {hive_server_hook:162} INFO - Written 3140000 rows so far.
# [2021-01-07 15:23:46,713] {hive_server_hook:162} INFO - Written 3150000 rows so far.
# [2021-01-07 15:23:47,098] {hive_server_hook:162} INFO - Written 3160000 rows so far.
# [2021-01-07 15:23:47,513] {hive_server_hook:162} INFO - Written 3170000 rows so far.
# [2021-01-07 15:23:47,937] {hive_server_hook:162} INFO - Written 3180000 rows so far.
# [2021-01-07 15:23:48,358] {hive_server_hook:162} INFO - Written 3190000 rows so far.
# [2021-01-07 15:23:48,750] {hive_server_hook:162} INFO - Written 3200000 rows so far.
# [2021-01-07 15:23:49,165] {hive_server_hook:162} INFO - Written 3210000 rows so far.
# [2021-01-07 15:23:49,582] {hive_server_hook:162} INFO - Written 3220000 rows so far.
# [2021-01-07 15:23:49,997] {hive_server_hook:162} INFO - Written 3230000 rows so far.
# [2021-01-07 15:23:50,424] {hive_server_hook:162} INFO - Written 3240000 rows so far.
# [2021-01-07 15:23:50,843] {hive_server_hook:162} INFO - Written 3250000 rows so far.
# [2021-01-07 15:23:51,287] {hive_server_hook:162} INFO - Written 3260000 rows so far.
# [2021-01-07 15:23:51,728] {hive_server_hook:162} INFO - Written 3270000 rows so far.
# [2021-01-07 15:23:52,176] {hive_server_hook:162} INFO - Written 3280000 rows so far.
# [2021-01-07 15:23:52,584] {hive_server_hook:162} INFO - Written 3290000 rows so far.
# [2021-01-07 15:23:52,997] {hive_server_hook:162} INFO - Written 3300000 rows so far.
# [2021-01-07 15:23:53,411] {hive_server_hook:162} INFO - Written 3310000 rows so far.
# [2021-01-07 15:23:53,845] {hive_server_hook:162} INFO - Written 3320000 rows so far.
# [2021-01-07 15:23:54,249] {hive_server_hook:162} INFO - Written 3330000 rows so far.
# [2021-01-07 15:23:54,683] {hive_server_hook:162} INFO - Written 3340000 rows so far.
# [2021-01-07 15:23:55,117] {hive_server_hook:162} INFO - Written 3350000 rows so far.
# [2021-01-07 15:23:55,563] {hive_server_hook:162} INFO - Written 3360000 rows so far.
# [2021-01-07 15:23:55,992] {hive_server_hook:162} INFO - Written 3370000 rows so far.
# [2021-01-07 15:23:56,398] {hive_server_hook:162} INFO - Written 3380000 rows so far.
# [2021-01-07 15:23:56,839] {hive_server_hook:162} INFO - Written 3390000 rows so far.
# [2021-01-07 15:23:57,266] {hive_server_hook:162} INFO - Written 3400000 rows so far.
# [2021-01-07 15:23:57,695] {hive_server_hook:162} INFO - Written 3410000 rows so far.
# [2021-01-07 15:23:58,111] {hive_server_hook:162} INFO - Written 3420000 rows so far.
# [2021-01-07 15:23:58,537] {hive_server_hook:162} INFO - Written 3430000 rows so far.
# [2021-01-07 15:23:58,965] {hive_server_hook:162} INFO - Written 3440000 rows so far.
# [2021-01-07 15:23:59,401] {hive_server_hook:162} INFO - Written 3450000 rows so far.
# [2021-01-07 15:23:59,863] {hive_server_hook:162} INFO - Written 3460000 rows so far.
# [2021-01-07 15:24:00,303] {hive_server_hook:162} INFO - Written 3470000 rows so far.
# [2021-01-07 15:24:00,751] {hive_server_hook:162} INFO - Written 3480000 rows so far.
# [2021-01-07 15:24:01,195] {hive_server_hook:162} INFO - Written 3490000 rows so far.
# [2021-01-07 15:24:01,598] {hive_server_hook:162} INFO - Written 3500000 rows so far.
# [2021-01-07 15:24:02,028] {hive_server_hook:162} INFO - Written 3510000 rows so far.
# [2021-01-07 15:24:02,456] {hive_server_hook:162} INFO - Written 3520000 rows so far.
# [2021-01-07 15:24:02,902] {hive_server_hook:162} INFO - Written 3530000 rows so far.
# [2021-01-07 15:24:03,378] {hive_server_hook:162} INFO - Written 3540000 rows so far.
# [2021-01-07 15:24:03,824] {hive_server_hook:162} INFO - Written 3550000 rows so far.
# [2021-01-07 15:24:04,293] {hive_server_hook:162} INFO - Written 3560000 rows so far.
# [2021-01-07 15:24:04,769] {hive_server_hook:162} INFO - Written 3570000 rows so far.
# [2021-01-07 15:24:05,250] {hive_server_hook:162} INFO - Written 3580000 rows so far.
# [2021-01-07 15:24:05,698] {hive_server_hook:162} INFO - Written 3590000 rows so far.
# [2021-01-07 15:24:06,176] {hive_server_hook:162} INFO - Written 3600000 rows so far.
# [2021-01-07 15:24:06,644] {hive_server_hook:162} INFO - Written 3610000 rows so far.
# [2021-01-07 15:24:07,145] {hive_server_hook:162} INFO - Written 3620000 rows so far.
# [2021-01-07 15:24:07,588] {hive_server_hook:162} INFO - Written 3630000 rows so far.
# [2021-01-07 15:24:08,063] {hive_server_hook:162} INFO - Written 3640000 rows so far.
# [2021-01-07 15:24:08,540] {hive_server_hook:162} INFO - Written 3650000 rows so far.
# [2021-01-07 15:24:09,019] {hive_server_hook:162} INFO - Written 3660000 rows so far.
# [2021-01-07 15:24:09,468] {hive_server_hook:162} INFO - Written 3670000 rows so far.
# [2021-01-07 15:24:09,946] {hive_server_hook:162} INFO - Written 3680000 rows so far.
# [2021-01-07 15:24:10,418] {hive_server_hook:162} INFO - Written 3690000 rows so far.
# [2021-01-07 15:24:10,899] {hive_server_hook:162} INFO - Written 3700000 rows so far.
# [2021-01-07 15:24:11,388] {hive_server_hook:162} INFO - Written 3710000 rows so far.
# [2021-01-07 15:24:11,832] {hive_server_hook:162} INFO - Written 3720000 rows so far.
# [2021-01-07 15:24:12,295] {hive_server_hook:162} INFO - Written 3730000 rows so far.
# [2021-01-07 15:24:12,733] {hive_server_hook:162} INFO - Written 3740000 rows so far.
# [2021-01-07 15:24:13,178] {hive_server_hook:162} INFO - Written 3750000 rows so far.
# [2021-01-07 15:24:13,602] {hive_server_hook:162} INFO - Written 3760000 rows so far.
# [2021-01-07 15:24:14,058] {hive_server_hook:162} INFO - Written 3770000 rows so far.
# [2021-01-07 15:24:14,523] {hive_server_hook:162} INFO - Written 3780000 rows so far.
# [2021-01-07 15:24:14,988] {hive_server_hook:162} INFO - Written 3790000 rows so far.
# [2021-01-07 15:24:15,425] {hive_server_hook:162} INFO - Written 3800000 rows so far.
# [2021-01-07 15:24:15,885] {hive_server_hook:162} INFO - Written 3810000 rows so far.
# [2021-01-07 15:24:16,346] {hive_server_hook:162} INFO - Written 3820000 rows so far.
# [2021-01-07 15:24:16,806] {hive_server_hook:162} INFO - Written 3830000 rows so far.
# [2021-01-07 15:24:17,251] {hive_server_hook:162} INFO - Written 3840000 rows so far.
# [2021-01-07 15:24:17,716] {hive_server_hook:162} INFO - Written 3850000 rows so far.
# [2021-01-07 15:24:18,181] {hive_server_hook:162} INFO - Written 3860000 rows so far.
# [2021-01-07 15:24:18,645] {hive_server_hook:162} INFO - Written 3870000 rows so far.
# [2021-01-07 15:24:19,115] {hive_server_hook:162} INFO - Written 3880000 rows so far.
# [2021-01-07 15:24:19,555] {hive_server_hook:162} INFO - Written 3890000 rows so far.
# [2021-01-07 15:24:20,014] {hive_server_hook:162} INFO - Written 3900000 rows so far.
# [2021-01-07 15:24:20,484] {hive_server_hook:162} INFO - Written 3910000 rows so far.
# [2021-01-07 15:24:20,950] {hive_server_hook:162} INFO - Written 3920000 rows so far.
# [2021-01-07 15:24:21,369] {hive_server_hook:162} INFO - Written 3930000 rows so far.
# [2021-01-07 15:24:21,841] {hive_server_hook:162} INFO - Written 3940000 rows so far.
# [2021-01-07 15:24:22,297] {hive_server_hook:162} INFO - Written 3950000 rows so far.
# [2021-01-07 15:24:22,752] {hive_server_hook:162} INFO - Written 3960000 rows so far.
# [2021-01-07 15:24:23,182] {hive_server_hook:162} INFO - Written 3970000 rows so far.
# [2021-01-07 15:24:23,644] {hive_server_hook:162} INFO - Written 3980000 rows so far.
# [2021-01-07 15:24:24,103] {hive_server_hook:162} INFO - Written 3990000 rows so far.
# [2021-01-07 15:24:24,561] {hive_server_hook:162} INFO - Written 4000000 rows so far.
# [2021-01-07 15:24:25,018] {hive_server_hook:162} INFO - Written 4010000 rows so far.
# [2021-01-07 15:24:25,451] {hive_server_hook:162} INFO - Written 4020000 rows so far.
# [2021-01-07 15:24:25,909] {hive_server_hook:162} INFO - Written 4030000 rows so far.
# [2021-01-07 15:24:26,370] {hive_server_hook:162} INFO - Written 4040000 rows so far.
# [2021-01-07 15:24:26,825] {hive_server_hook:162} INFO - Written 4050000 rows so far.
# [2021-01-07 15:24:27,249] {hive_server_hook:162} INFO - Written 4060000 rows so far.
# [2021-01-07 15:24:27,709] {hive_server_hook:162} INFO - Written 4070000 rows so far.
# [2021-01-07 15:24:28,168] {hive_server_hook:162} INFO - Written 4080000 rows so far.
# [2021-01-07 15:24:28,626] {hive_server_hook:162} INFO - Written 4090000 rows so far.
# [2021-01-07 15:24:29,064] {hive_server_hook:162} INFO - Written 4100000 rows so far.
# [2021-01-07 15:24:29,522] {hive_server_hook:162} INFO - Written 4110000 rows so far.
# [2021-01-07 15:24:29,976] {hive_server_hook:162} INFO - Written 4120000 rows so far.
# [2021-01-07 15:24:30,440] {hive_server_hook:162} INFO - Written 4130000 rows so far.
# [2021-01-07 15:24:30,867] {hive_server_hook:162} INFO - Written 4140000 rows so far.
# [2021-01-07 15:24:31,321] {hive_server_hook:162} INFO - Written 4150000 rows so far.
# [2021-01-07 15:24:31,781] {hive_server_hook:162} INFO - Written 4160000 rows so far.
# [2021-01-07 15:24:32,239] {hive_server_hook:162} INFO - Written 4170000 rows so far.
# [2021-01-07 15:24:32,696] {hive_server_hook:162} INFO - Written 4180000 rows so far.
# [2021-01-07 15:24:33,124] {hive_server_hook:162} INFO - Written 4190000 rows so far.
# [2021-01-07 15:24:33,582] {hive_server_hook:162} INFO - Written 4200000 rows so far.
# [2021-01-07 15:24:34,039] {hive_server_hook:162} INFO - Written 4210000 rows so far.
# [2021-01-07 15:24:34,509] {hive_server_hook:162} INFO - Written 4220000 rows so far.
# [2021-01-07 15:24:34,937] {hive_server_hook:162} INFO - Written 4230000 rows so far.
# [2021-01-07 15:24:35,397] {hive_server_hook:162} INFO - Written 4240000 rows so far.
# [2021-01-07 15:24:35,858] {hive_server_hook:162} INFO - Written 4250000 rows so far.
# [2021-01-07 15:24:36,312] {hive_server_hook:162} INFO - Written 4260000 rows so far.
# [2021-01-07 15:24:36,744] {hive_server_hook:162} INFO - Written 4270000 rows so far.
# [2021-01-07 15:24:37,202] {hive_server_hook:162} INFO - Written 4280000 rows so far.
# [2021-01-07 15:24:37,660] {hive_server_hook:162} INFO - Written 4290000 rows so far.
# [2021-01-07 15:24:38,143] {hive_server_hook:162} INFO - Written 4300000 rows so far.
# [2021-01-07 15:24:38,567] {hive_server_hook:162} INFO - Written 4310000 rows so far.
# [2021-01-07 15:24:39,025] {hive_server_hook:162} INFO - Written 4320000 rows so far.
# [2021-01-07 15:24:39,483] {hive_server_hook:162} INFO - Written 4330000 rows so far.
# [2021-01-07 15:24:39,941] {hive_server_hook:162} INFO - Written 4340000 rows so far.
# [2021-01-07 15:24:40,399] {hive_server_hook:162} INFO - Written 4350000 rows so far.
# [2021-01-07 15:24:40,826] {hive_server_hook:162} INFO - Written 4360000 rows so far.
# [2021-01-07 15:24:41,286] {hive_server_hook:162} INFO - Written 4370000 rows so far.
# [2021-01-07 15:24:41,746] {hive_server_hook:162} INFO - Written 4380000 rows so far.
# [2021-01-07 15:24:42,204] {hive_server_hook:162} INFO - Written 4390000 rows so far.
# [2021-01-07 15:24:42,636] {hive_server_hook:162} INFO - Written 4400000 rows so far.
# [2021-01-07 15:24:43,095] {hive_server_hook:162} INFO - Written 4410000 rows so far.
# [2021-01-07 15:24:43,552] {hive_server_hook:162} INFO - Written 4420000 rows so far.
# [2021-01-07 15:24:44,010] {hive_server_hook:162} INFO - Written 4430000 rows so far.
# [2021-01-07 15:24:44,440] {hive_server_hook:162} INFO - Written 4440000 rows so far.
# [2021-01-07 15:24:44,900] {hive_server_hook:162} INFO - Written 4450000 rows so far.
# [2021-01-07 15:24:45,361] {hive_server_hook:162} INFO - Written 4460000 rows so far.
# [2021-01-07 15:24:45,819] {hive_server_hook:162} INFO - Written 4470000 rows so far.
# [2021-01-07 15:24:46,241] {hive_server_hook:162} INFO - Written 4480000 rows so far.
# [2021-01-07 15:24:46,702] {hive_server_hook:162} INFO - Written 4490000 rows so far.
# [2021-01-07 15:24:47,159] {hive_server_hook:162} INFO - Written 4500000 rows so far.
# [2021-01-07 15:24:47,616] {hive_server_hook:162} INFO - Written 4510000 rows so far.
# [2021-01-07 15:24:48,073] {hive_server_hook:162} INFO - Written 4520000 rows so far.
# [2021-01-07 15:24:48,504] {hive_server_hook:162} INFO - Written 4530000 rows so far.
# [2021-01-07 15:24:48,957] {hive_server_hook:162} INFO - Written 4540000 rows so far.
# [2021-01-07 15:24:49,412] {hive_server_hook:162} INFO - Written 4550000 rows so far.
# [2021-01-07 15:24:49,876] {hive_server_hook:162} INFO - Written 4560000 rows so far.
# [2021-01-07 15:24:50,309] {hive_server_hook:162} INFO - Written 4570000 rows so far.
# [2021-01-07 15:24:50,768] {hive_server_hook:162} INFO - Written 4580000 rows so far.
# [2021-01-07 15:24:51,232] {hive_server_hook:162} INFO - Written 4590000 rows so far.
# [2021-01-07 15:24:51,713] {hive_server_hook:162} INFO - Written 4600000 rows so far.
# [2021-01-07 15:24:52,145] {hive_server_hook:162} INFO - Written 4610000 rows so far.
# [2021-01-07 15:24:52,607] {hive_server_hook:162} INFO - Written 4620000 rows so far.
# [2021-01-07 15:24:53,066] {hive_server_hook:162} INFO - Written 4630000 rows so far.
# [2021-01-07 15:24:53,522] {hive_server_hook:162} INFO - Written 4640000 rows so far.
# [2021-01-07 15:24:53,985] {hive_server_hook:162} INFO - Written 4650000 rows so far.
# [2021-01-07 15:24:54,406] {hive_server_hook:162} INFO - Written 4660000 rows so far.
# [2021-01-07 15:24:54,867] {hive_server_hook:162} INFO - Written 4670000 rows so far.
# [2021-01-07 15:24:55,329] {hive_server_hook:162} INFO - Written 4680000 rows so far.
# [2021-01-07 15:24:55,792] {hive_server_hook:162} INFO - Written 4690000 rows so far.
# [2021-01-07 15:24:56,226] {hive_server_hook:162} INFO - Written 4700000 rows so far.
# [2021-01-07 15:24:56,686] {hive_server_hook:162} INFO - Written 4710000 rows so far.
# [2021-01-07 15:24:57,149] {hive_server_hook:162} INFO - Written 4720000 rows so far.
# [2021-01-07 15:24:57,609] {hive_server_hook:162} INFO - Written 4730000 rows so far.
# [2021-01-07 15:24:58,044] {hive_server_hook:162} INFO - Written 4740000 rows so far.
# [2021-01-07 15:24:58,503] {hive_server_hook:162} INFO - Written 4750000 rows so far.
# [2021-01-07 15:24:58,964] {hive_server_hook:162} INFO - Written 4760000 rows so far.
# [2021-01-07 15:24:59,423] {hive_server_hook:162} INFO - Written 4770000 rows so far.
# [2021-01-07 15:24:59,849] {hive_server_hook:162} INFO - Written 4780000 rows so far.
# [2021-01-07 15:25:00,312] {hive_server_hook:162} INFO - Written 4790000 rows so far.
# [2021-01-07 15:25:00,791] {hive_server_hook:162} INFO - Written 4800000 rows so far.
# [2021-01-07 15:25:01,250] {hive_server_hook:162} INFO - Written 4810000 rows so far.
# [2021-01-07 15:25:01,710] {hive_server_hook:162} INFO - Written 4820000 rows so far.
# [2021-01-07 15:25:02,142] {hive_server_hook:162} INFO - Written 4830000 rows so far.
# [2021-01-07 15:25:02,591] {hive_server_hook:162} INFO - Written 4840000 rows so far.
# [2021-01-07 15:25:03,051] {hive_server_hook:162} INFO - Written 4850000 rows so far.
# [2021-01-07 15:25:03,509] {hive_server_hook:162} INFO - Written 4860000 rows so far.
# [2021-01-07 15:25:03,935] {hive_server_hook:162} INFO - Written 4870000 rows so far.
# [2021-01-07 15:25:04,391] {hive_server_hook:162} INFO - Written 4880000 rows so far.
# [2021-01-07 15:25:04,848] {hive_server_hook:162} INFO - Written 4890000 rows so far.
# [2021-01-07 15:25:05,312] {hive_server_hook:162} INFO - Written 4900000 rows so far.
# [2021-01-07 15:25:05,743] {hive_server_hook:162} INFO - Written 4910000 rows so far.
# [2021-01-07 15:25:06,206] {hive_server_hook:162} INFO - Written 4920000 rows so far.
# [2021-01-07 15:25:06,684] {hive_server_hook:162} INFO - Written 4930000 rows so far.
# [2021-01-07 15:25:07,158] {hive_server_hook:162} INFO - Written 4940000 rows so far.
# [2021-01-07 15:25:07,594] {hive_server_hook:162} INFO - Written 4950000 rows so far.
# [2021-01-07 15:25:08,057] {hive_server_hook:162} INFO - Written 4960000 rows so far.
# [2021-01-07 15:25:08,514] {hive_server_hook:162} INFO - Written 4970000 rows so far.
# [2021-01-07 15:25:08,970] {hive_server_hook:162} INFO - Written 4980000 rows so far.
# [2021-01-07 15:25:09,476] {hive_server_hook:162} INFO - Written 4990000 rows so far.
# [2021-01-07 15:25:09,919] {hive_server_hook:162} INFO - Written 5000000 rows so far.
# [2021-01-07 15:25:10,381] {hive_server_hook:162} INFO - Written 5010000 rows so far.
# [2021-01-07 15:25:10,831] {hive_server_hook:162} INFO - Written 5020000 rows so far.
# [2021-01-07 15:25:11,283] {hive_server_hook:162} INFO - Written 5030000 rows so far.
# [2021-01-07 15:25:11,690] {hive_server_hook:162} INFO - Written 5040000 rows so far.
# [2021-01-07 15:25:12,110] {hive_server_hook:162} INFO - Written 5050000 rows so far.
# [2021-01-07 15:25:12,529] {hive_server_hook:162} INFO - Written 5060000 rows so far.
# [2021-01-07 15:25:12,952] {hive_server_hook:162} INFO - Written 5070000 rows so far.
# [2021-01-07 15:25:13,349] {hive_server_hook:162} INFO - Written 5080000 rows so far.
# [2021-01-07 15:25:13,776] {hive_server_hook:162} INFO - Written 5090000 rows so far.
# [2021-01-07 15:25:14,202] {hive_server_hook:162} INFO - Written 5100000 rows so far.
# [2021-01-07 15:25:14,628] {hive_server_hook:162} INFO - Written 5110000 rows so far.
# [2021-01-07 15:25:15,025] {hive_server_hook:162} INFO - Written 5120000 rows so far.
# [2021-01-07 15:25:15,450] {hive_server_hook:162} INFO - Written 5130000 rows so far.
# [2021-01-07 15:25:15,874] {hive_server_hook:162} INFO - Written 5140000 rows so far.
# [2021-01-07 15:25:16,297] {hive_server_hook:162} INFO - Written 5150000 rows so far.
# [2021-01-07 15:25:16,718] {hive_server_hook:162} INFO - Written 5160000 rows so far.
# [2021-01-07 15:25:17,120] {hive_server_hook:162} INFO - Written 5170000 rows so far.
# [2021-01-07 15:25:17,545] {hive_server_hook:162} INFO - Written 5180000 rows so far.
# [2021-01-07 15:25:17,964] {hive_server_hook:162} INFO - Written 5190000 rows so far.
# [2021-01-07 15:25:18,384] {hive_server_hook:162} INFO - Written 5200000 rows so far.
# [2021-01-07 15:25:18,775] {hive_server_hook:162} INFO - Written 5210000 rows so far.
# [2021-01-07 15:25:19,194] {hive_server_hook:162} INFO - Written 5220000 rows so far.
# [2021-01-07 15:25:19,611] {hive_server_hook:162} INFO - Written 5230000 rows so far.
# [2021-01-07 15:25:20,029] {hive_server_hook:162} INFO - Written 5240000 rows so far.
# [2021-01-07 15:25:20,435] {hive_server_hook:162} INFO - Written 5250000 rows so far.
# [2021-01-07 15:25:20,860] {hive_server_hook:162} INFO - Written 5260000 rows so far.
# [2021-01-07 15:25:21,278] {hive_server_hook:162} INFO - Written 5270000 rows so far.
# [2021-01-07 15:25:21,699] {hive_server_hook:162} INFO - Written 5280000 rows so far.
# [2021-01-07 15:25:22,117] {hive_server_hook:162} INFO - Written 5290000 rows so far.
# [2021-01-07 15:25:22,509] {hive_server_hook:162} INFO - Written 5300000 rows so far.
# [2021-01-07 15:25:22,928] {hive_server_hook:162} INFO - Written 5310000 rows so far.
# [2021-01-07 15:25:23,351] {hive_server_hook:162} INFO - Written 5320000 rows so far.
# [2021-01-07 15:25:23,769] {hive_server_hook:162} INFO - Written 5330000 rows so far.
# [2021-01-07 15:25:24,164] {hive_server_hook:162} INFO - Written 5340000 rows so far.
# [2021-01-07 15:25:24,582] {hive_server_hook:162} INFO - Written 5350000 rows so far.
# [2021-01-07 15:25:25,003] {hive_server_hook:162} INFO - Written 5360000 rows so far.
# [2021-01-07 15:25:25,427] {hive_server_hook:162} INFO - Written 5370000 rows so far.
# [2021-01-07 15:25:25,820] {hive_server_hook:162} INFO - Written 5380000 rows so far.
# [2021-01-07 15:25:26,240] {hive_server_hook:162} INFO - Written 5390000 rows so far.
# [2021-01-07 15:25:26,656] {hive_server_hook:162} INFO - Written 5400000 rows so far.
# [2021-01-07 15:25:27,074] {hive_server_hook:162} INFO - Written 5410000 rows so far.
# [2021-01-07 15:25:27,464] {hive_server_hook:162} INFO - Written 5420000 rows so far.
# [2021-01-07 15:25:27,880] {hive_server_hook:162} INFO - Written 5430000 rows so far.
# [2021-01-07 15:25:28,307] {hive_server_hook:162} INFO - Written 5440000 rows so far.
# [2021-01-07 15:25:28,731] {hive_server_hook:162} INFO - Written 5450000 rows so far.
# [2021-01-07 15:25:29,156] {hive_server_hook:162} INFO - Written 5460000 rows so far.
# [2021-01-07 15:25:29,552] {hive_server_hook:162} INFO - Written 5470000 rows so far.
# [2021-01-07 15:25:29,976] {hive_server_hook:162} INFO - Written 5480000 rows so far.
# [2021-01-07 15:25:30,415] {hive_server_hook:162} INFO - Written 5490000 rows so far.
# [2021-01-07 15:25:30,847] {hive_server_hook:162} INFO - Written 5500000 rows so far.
# [2021-01-07 15:25:31,251] {hive_server_hook:162} INFO - Written 5510000 rows so far.
# [2021-01-07 15:25:31,678] {hive_server_hook:162} INFO - Written 5520000 rows so far.
# [2021-01-07 15:25:32,105] {hive_server_hook:162} INFO - Written 5530000 rows so far.
# [2021-01-07 15:25:32,534] {hive_server_hook:162} INFO - Written 5540000 rows so far.
# [2021-01-07 15:25:32,932] {hive_server_hook:162} INFO - Written 5550000 rows so far.
# [2021-01-07 15:25:33,353] {hive_server_hook:162} INFO - Written 5560000 rows so far.
# [2021-01-07 15:25:33,777] {hive_server_hook:162} INFO - Written 5570000 rows so far.
# [2021-01-07 15:25:34,198] {hive_server_hook:162} INFO - Written 5580000 rows so far.
# [2021-01-07 15:25:34,593] {hive_server_hook:162} INFO - Written 5590000 rows so far.
# [2021-01-07 15:25:35,017] {hive_server_hook:162} INFO - Written 5600000 rows so far.
# [2021-01-07 15:25:35,436] {hive_server_hook:162} INFO - Written 5610000 rows so far.
# [2021-01-07 15:25:35,855] {hive_server_hook:162} INFO - Written 5620000 rows so far.
# [2021-01-07 15:25:36,282] {hive_server_hook:162} INFO - Written 5630000 rows so far.
# [2021-01-07 15:25:36,672] {hive_server_hook:162} INFO - Written 5640000 rows so far.
# [2021-01-07 15:25:37,095] {hive_server_hook:162} INFO - Written 5650000 rows so far.
# [2021-01-07 15:25:37,515] {hive_server_hook:162} INFO - Written 5660000 rows so far.
# [2021-01-07 15:25:37,936] {hive_server_hook:162} INFO - Written 5670000 rows so far.
# [2021-01-07 15:25:38,329] {hive_server_hook:162} INFO - Written 5680000 rows so far.
# [2021-01-07 15:25:38,748] {hive_server_hook:162} INFO - Written 5690000 rows so far.
# [2021-01-07 15:25:39,166] {hive_server_hook:162} INFO - Written 5700000 rows so far.
# [2021-01-07 15:25:39,585] {hive_server_hook:162} INFO - Written 5710000 rows so far.
# [2021-01-07 15:25:39,973] {hive_server_hook:162} INFO - Written 5720000 rows so far.
# [2021-01-07 15:25:40,402] {hive_server_hook:162} INFO - Written 5730000 rows so far.
# [2021-01-07 15:25:40,820] {hive_server_hook:162} INFO - Written 5740000 rows so far.
# [2021-01-07 15:25:41,236] {hive_server_hook:162} INFO - Written 5750000 rows so far.
# [2021-01-07 15:25:41,632] {hive_server_hook:162} INFO - Written 5760000 rows so far.
# [2021-01-07 15:25:42,053] {hive_server_hook:162} INFO - Written 5770000 rows so far.
# [2021-01-07 15:25:42,483] {hive_server_hook:162} INFO - Written 5780000 rows so far.
# [2021-01-07 15:25:42,907] {hive_server_hook:162} INFO - Written 5790000 rows so far.
# [2021-01-07 15:25:43,332] {hive_server_hook:162} INFO - Written 5800000 rows so far.
# [2021-01-07 15:25:43,727] {hive_server_hook:162} INFO - Written 5810000 rows so far.
# [2021-01-07 15:25:44,148] {hive_server_hook:162} INFO - Written 5820000 rows so far.
# [2021-01-07 15:25:44,564] {hive_server_hook:162} INFO - Written 5830000 rows so far.
# [2021-01-07 15:25:44,988] {hive_server_hook:162} INFO - Written 5840000 rows so far.
# [2021-01-07 15:25:45,393] {hive_server_hook:162} INFO - Written 5850000 rows so far.
# [2021-01-07 15:25:45,813] {hive_server_hook:162} INFO - Written 5860000 rows so far.
# [2021-01-07 15:25:46,239] {hive_server_hook:162} INFO - Written 5870000 rows so far.
# [2021-01-07 15:25:46,670] {hive_server_hook:162} INFO - Written 5880000 rows so far.
# [2021-01-07 15:25:47,070] {hive_server_hook:162} INFO - Written 5890000 rows so far.
# [2021-01-07 15:25:47,507] {hive_server_hook:162} INFO - Written 5900000 rows so far.
# [2021-01-07 15:25:47,935] {hive_server_hook:162} INFO - Written 5910000 rows so far.
# [2021-01-07 15:25:48,361] {hive_server_hook:162} INFO - Written 5920000 rows so far.
# [2021-01-07 15:25:48,803] {hive_server_hook:162} INFO - Written 5930000 rows so far.
# [2021-01-07 15:25:49,201] {hive_server_hook:162} INFO - Written 5940000 rows so far.
# [2021-01-07 15:25:49,625] {hive_server_hook:162} INFO - Written 5950000 rows so far.
# [2021-01-07 15:25:50,057] {hive_server_hook:162} INFO - Written 5960000 rows so far.
# [2021-01-07 15:25:50,490] {hive_server_hook:162} INFO - Written 5970000 rows so far.
# [2021-01-07 15:25:50,893] {hive_server_hook:162} INFO - Written 5980000 rows so far.
# [2021-01-07 15:25:51,321] {hive_server_hook:162} INFO - Written 5990000 rows so far.
# [2021-01-07 15:25:51,746] {hive_server_hook:162} INFO - Written 6000000 rows so far.
# [2021-01-07 15:25:52,177] {hive_server_hook:162} INFO - Written 6010000 rows so far.
# [2021-01-07 15:25:52,573] {hive_server_hook:162} INFO - Written 6020000 rows so far.
# [2021-01-07 15:25:52,999] {hive_server_hook:162} INFO - Written 6030000 rows so far.
# [2021-01-07 15:25:53,426] {hive_server_hook:162} INFO - Written 6040000 rows so far.
# [2021-01-07 15:25:53,854] {hive_server_hook:162} INFO - Written 6050000 rows so far.
# [2021-01-07 15:25:54,253] {hive_server_hook:162} INFO - Written 6060000 rows so far.
# [2021-01-07 15:25:54,673] {hive_server_hook:162} INFO - Written 6070000 rows so far.
# [2021-01-07 15:25:55,094] {hive_server_hook:162} INFO - Written 6080000 rows so far.
# [2021-01-07 15:25:55,528] {hive_server_hook:162} INFO - Written 6090000 rows so far.
# [2021-01-07 15:25:55,947] {hive_server_hook:162} INFO - Written 6100000 rows so far.
# [2021-01-07 15:25:56,336] {hive_server_hook:162} INFO - Written 6110000 rows so far.
# [2021-01-07 15:25:56,755] {hive_server_hook:162} INFO - Written 6120000 rows so far.
# [2021-01-07 15:25:57,169] {hive_server_hook:162} INFO - Written 6130000 rows so far.
# [2021-01-07 15:25:57,584] {hive_server_hook:162} INFO - Written 6140000 rows so far.
# [2021-01-07 15:25:57,970] {hive_server_hook:162} INFO - Written 6150000 rows so far.
# [2021-01-07 15:25:58,387] {hive_server_hook:162} INFO - Written 6160000 rows so far.
# [2021-01-07 15:25:58,803] {hive_server_hook:162} INFO - Written 6170000 rows so far.
# [2021-01-07 15:25:59,220] {hive_server_hook:162} INFO - Written 6180000 rows so far.
# [2021-01-07 15:25:59,609] {hive_server_hook:162} INFO - Written 6190000 rows so far.
# [2021-01-07 15:26:00,031] {hive_server_hook:162} INFO - Written 6200000 rows so far.
# [2021-01-07 15:26:00,466] {hive_server_hook:162} INFO - Written 6210000 rows so far.
# [2021-01-07 15:26:00,890] {hive_server_hook:162} INFO - Written 6220000 rows so far.
# [2021-01-07 15:26:01,282] {hive_server_hook:162} INFO - Written 6230000 rows so far.
# [2021-01-07 15:26:01,702] {hive_server_hook:162} INFO - Written 6240000 rows so far.
# [2021-01-07 15:26:02,120] {hive_server_hook:162} INFO - Written 6250000 rows so far.
# [2021-01-07 15:26:02,535] {hive_server_hook:162} INFO - Written 6260000 rows so far.
# [2021-01-07 15:26:02,949] {hive_server_hook:162} INFO - Written 6270000 rows so far.
# [2021-01-07 15:26:03,337] {hive_server_hook:162} INFO - Written 6280000 rows so far.
# [2021-01-07 15:26:03,749] {hive_server_hook:162} INFO - Written 6290000 rows so far.
# [2021-01-07 15:26:04,163] {hive_server_hook:162} INFO - Written 6300000 rows so far.
# [2021-01-07 15:26:04,588] {hive_server_hook:162} INFO - Written 6310000 rows so far.
# [2021-01-07 15:26:04,981] {hive_server_hook:162} INFO - Written 6320000 rows so far.
# [2021-01-07 15:26:05,397] {hive_server_hook:162} INFO - Written 6330000 rows so far.
# [2021-01-07 15:26:05,815] {hive_server_hook:162} INFO - Written 6340000 rows so far.
# [2021-01-07 15:26:06,234] {hive_server_hook:162} INFO - Written 6350000 rows so far.
# [2021-01-07 15:26:06,488] {hive_server_hook:162} INFO - Written 6356658 rows so far.
# [2021-01-07 15:26:06,499] {hiveserver2:265} INFO - Closing active operation
# [2021-01-07 15:26:06,537] {hive_server_hook:163} INFO - Done. Loaded a total of 6356658 rows.
# [2021-01-07 15:26:18,163] {<ipython-input-2-bac83ce33734>:84} INFO - 读取数据完成.............

# %%
## 重命名
dl_site_ts_order_clean = dl_site_ts_order_clean.rename(columns={'license_year':'license_time_year','pay_year':'publish_time_year'})

# %%
## 剔除极大或者极小的峰值
dl_site_ts_order_clean_count = dl_site_ts_order_clean[['model_code','license_time_year','real_pay_amount']].\
groupby(['model_code','license_time_year']).count().reset_index().rename(columns={'real_pay_amount':'count'})

dl_site_ts_order_clean_mean = dl_site_ts_order_clean[['model_code','license_time_year','real_pay_amount']].\
groupby(['model_code','license_time_year']).mean().reset_index().rename(columns={'real_pay_amount':'mean'})

dl_site_ts_order_clean_std = dl_site_ts_order_clean[['model_code','license_time_year','real_pay_amount']].\
groupby(['model_code','license_time_year']).std().reset_index().rename(columns={'real_pay_amount':'std'})

dl_site_ts_order_clean_median = dl_site_ts_order_clean[['model_code','license_time_year','real_pay_amount']].\
groupby(['model_code','license_time_year']).median().reset_index().rename(columns={'real_pay_amount':'median'})

dl_site_ts_order_clean_min = dl_site_ts_order_clean[['model_code','license_time_year','real_pay_amount']].\
groupby(['model_code','license_time_year']).min().reset_index().rename(columns={'real_pay_amount':'min_price'})

dl_site_ts_order_clean_max = dl_site_ts_order_clean[['model_code','license_time_year','real_pay_amount']].\
groupby(['model_code','license_time_year']).max().reset_index().rename(columns={'real_pay_amount':'max_price'})

dl_site_ts_order_clean = pd.merge(dl_site_ts_order_clean,dl_site_ts_order_clean_count,on=['model_code','license_time_year'],how='left')
dl_site_ts_order_clean = pd.merge(dl_site_ts_order_clean,dl_site_ts_order_clean_mean,on=['model_code','license_time_year'],how='left')
dl_site_ts_order_clean = pd.merge(dl_site_ts_order_clean,dl_site_ts_order_clean_std,on=['model_code','license_time_year'],how='left')
dl_site_ts_order_clean = pd.merge(dl_site_ts_order_clean,dl_site_ts_order_clean_min,on=['model_code','license_time_year'],how='left')
dl_site_ts_order_clean = pd.merge(dl_site_ts_order_clean,dl_site_ts_order_clean_max,on=['model_code','license_time_year'],how='left')
dl_site_ts_order_clean = pd.merge(dl_site_ts_order_clean,dl_site_ts_order_clean_median,on=['model_code','license_time_year'],how='left')

dl_site_ts_order_clean.loc[dl_site_ts_order_clean['mean']*0.3 < dl_site_ts_order_clean['std'],'std'] = dl_site_ts_order_clean['mean']*0.3

dl_site_ts_order_clean.loc[(dl_site_ts_order_clean['median'] > dl_site_ts_order_clean['mean']) & 
#                           (dl_site_ts_order_clean['mean']*0.5 <= dl_site_ts_order_clean['std']) & 
                          (dl_site_ts_order_clean['real_pay_amount'] < dl_site_ts_order_clean['mean']-dl_site_ts_order_clean['std']),'delete_flag'] = 1

dl_site_ts_order_clean.loc[(dl_site_ts_order_clean['median'] < dl_site_ts_order_clean['mean']) & 
#                           (dl_site_ts_order_clean['mean']*0.5 <= dl_site_ts_order_clean['std']) & 
                          (dl_site_ts_order_clean['real_pay_amount'] > dl_site_ts_order_clean['mean']+dl_site_ts_order_clean['std']),'delete_flag'] = 1

dl_site_ts_order_clean.loc[(dl_site_ts_order_clean['median'] > dl_site_ts_order_clean['mean']) & 
#                           (dl_site_ts_order_clean['mean']*0.5 <= dl_site_ts_order_clean['std']) & 
                          (dl_site_ts_order_clean['real_pay_amount'] < dl_site_ts_order_clean['mean']-dl_site_ts_order_clean['std']),'real_pay_amount'] = dl_site_ts_order_clean['mean']-dl_site_ts_order_clean['std']

dl_site_ts_order_clean.loc[(dl_site_ts_order_clean['median'] < dl_site_ts_order_clean['mean']) & 
#                           (dl_site_ts_order_clean['mean']*0.5 <= dl_site_ts_order_clean['std']) & 
                          (dl_site_ts_order_clean['real_pay_amount'] > dl_site_ts_order_clean['mean']+dl_site_ts_order_clean['std']),'real_pay_amount'] = dl_site_ts_order_clean['mean']+dl_site_ts_order_clean['std']

# %%
## 剔除极大或者极小的峰值
dl_site_ts_order_clean_count = dl_site_ts_order_clean[['model_code','license_time_year','real_pay_amount']].\
groupby(['model_code','license_time_year']).count().reset_index().rename(columns={'real_pay_amount':'count_1'})

dl_site_ts_order_clean_mean = dl_site_ts_order_clean[['model_code','license_time_year','real_pay_amount']].\
groupby(['model_code','license_time_year']).mean().reset_index().rename(columns={'real_pay_amount':'mean_1'})

dl_site_ts_order_clean_std = dl_site_ts_order_clean[['model_code','license_time_year','real_pay_amount']].\
groupby(['model_code','license_time_year']).std().reset_index().rename(columns={'real_pay_amount':'std_1'})

dl_site_ts_order_clean_median = dl_site_ts_order_clean[['model_code','license_time_year','real_pay_amount']].\
groupby(['model_code','license_time_year']).median().reset_index().rename(columns={'real_pay_amount':'median_1'})

dl_site_ts_order_clean_min = dl_site_ts_order_clean[['model_code','license_time_year','real_pay_amount']].\
groupby(['model_code','license_time_year']).min().reset_index().rename(columns={'real_pay_amount':'min_price_1'})

dl_site_ts_order_clean_max = dl_site_ts_order_clean[['model_code','license_time_year','real_pay_amount']].\
groupby(['model_code','license_time_year']).max().reset_index().rename(columns={'real_pay_amount':'max_price_1'})

dl_site_ts_order_clean = pd.merge(dl_site_ts_order_clean,dl_site_ts_order_clean_count,on=['model_code','license_time_year'],how='left')
dl_site_ts_order_clean = pd.merge(dl_site_ts_order_clean,dl_site_ts_order_clean_mean,on=['model_code','license_time_year'],how='left')
dl_site_ts_order_clean = pd.merge(dl_site_ts_order_clean,dl_site_ts_order_clean_std,on=['model_code','license_time_year'],how='left')
dl_site_ts_order_clean = pd.merge(dl_site_ts_order_clean,dl_site_ts_order_clean_min,on=['model_code','license_time_year'],how='left')
dl_site_ts_order_clean = pd.merge(dl_site_ts_order_clean,dl_site_ts_order_clean_max,on=['model_code','license_time_year'],how='left')
dl_site_ts_order_clean = pd.merge(dl_site_ts_order_clean,dl_site_ts_order_clean_median,on=['model_code','license_time_year'],how='left')

## 剔除峰值
dl_site_ts_order_clean.loc[dl_site_ts_order_clean['mean_1']*0.3 < dl_site_ts_order_clean['std_1'],'std_1'] = dl_site_ts_order_clean['mean_1']*0.3

dl_site_ts_order_clean.loc[(dl_site_ts_order_clean['median_1'] > dl_site_ts_order_clean['mean_1']) & 
#                           (dl_site_ts_order_clean['mean']*0.5 <= dl_site_ts_order_clean['std']) & 
                          (dl_site_ts_order_clean['real_pay_amount'] < dl_site_ts_order_clean['mean_1']-dl_site_ts_order_clean['std_1']),'delete_flag_1'] = 1

dl_site_ts_order_clean.loc[(dl_site_ts_order_clean['median_1'] < dl_site_ts_order_clean['mean_1']) & 
#                           (dl_site_ts_order_clean['mean']*0.5 <= dl_site_ts_order_clean['std']) & 
                          (dl_site_ts_order_clean['real_pay_amount'] > dl_site_ts_order_clean['mean_1']+dl_site_ts_order_clean['std_1']),'delete_flag_1'] = 1

dl_site_ts_order_clean.loc[(dl_site_ts_order_clean['median_1'] > dl_site_ts_order_clean['mean_1']) & 
#                           (dl_site_ts_order_clean['mean']*0.5 <= dl_site_ts_order_clean['std']) & 
                          (dl_site_ts_order_clean['real_pay_amount'] < dl_site_ts_order_clean['mean_1']-dl_site_ts_order_clean['std_1']),'real_pay_amount'] = dl_site_ts_order_clean['mean_1']-dl_site_ts_order_clean['std_1']

dl_site_ts_order_clean.loc[(dl_site_ts_order_clean['median_1'] < dl_site_ts_order_clean['mean_1']) & 
#                           (dl_site_ts_order_clean['mean']*0.5 <= dl_site_ts_order_clean['std']) & 
                          (dl_site_ts_order_clean['real_pay_amount'] > dl_site_ts_order_clean['mean_1']+dl_site_ts_order_clean['std_1']),'real_pay_amount'] = dl_site_ts_order_clean['mean_1']+dl_site_ts_order_clean['std_1']

# %%
## 剔除极大或者极小的峰值
dl_site_ts_order_clean_count = dl_site_ts_order_clean[['model_code','license_time_year','real_pay_amount']].\
groupby(['model_code','license_time_year']).count().reset_index().rename(columns={'real_pay_amount':'count_2'})

dl_site_ts_order_clean_mean = dl_site_ts_order_clean[['model_code','license_time_year','real_pay_amount']].\
groupby(['model_code','license_time_year']).mean().reset_index().rename(columns={'real_pay_amount':'mean_2'})

dl_site_ts_order_clean_std = dl_site_ts_order_clean[['model_code','license_time_year','real_pay_amount']].\
groupby(['model_code','license_time_year']).std().reset_index().rename(columns={'real_pay_amount':'std_2'})

dl_site_ts_order_clean_median = dl_site_ts_order_clean[['model_code','license_time_year','real_pay_amount']].\
groupby(['model_code','license_time_year']).median().reset_index().rename(columns={'real_pay_amount':'median_2'})

dl_site_ts_order_clean_min = dl_site_ts_order_clean[['model_code','license_time_year','real_pay_amount']].\
groupby(['model_code','license_time_year']).min().reset_index().rename(columns={'real_pay_amount':'min_price_2'})

dl_site_ts_order_clean_max = dl_site_ts_order_clean[['model_code','license_time_year','real_pay_amount']].\
groupby(['model_code','license_time_year']).max().reset_index().rename(columns={'real_pay_amount':'max_price_2'})

dl_site_ts_order_clean = pd.merge(dl_site_ts_order_clean,dl_site_ts_order_clean_count,on=['model_code','license_time_year'],how='left')
dl_site_ts_order_clean = pd.merge(dl_site_ts_order_clean,dl_site_ts_order_clean_mean,on=['model_code','license_time_year'],how='left')
dl_site_ts_order_clean = pd.merge(dl_site_ts_order_clean,dl_site_ts_order_clean_std,on=['model_code','license_time_year'],how='left')
dl_site_ts_order_clean = pd.merge(dl_site_ts_order_clean,dl_site_ts_order_clean_min,on=['model_code','license_time_year'],how='left')
dl_site_ts_order_clean = pd.merge(dl_site_ts_order_clean,dl_site_ts_order_clean_max,on=['model_code','license_time_year'],how='left')
dl_site_ts_order_clean = pd.merge(dl_site_ts_order_clean,dl_site_ts_order_clean_median,on=['model_code','license_time_year'],how='left')

## 剔除峰值
dl_site_ts_order_clean.loc[dl_site_ts_order_clean['mean_2']*0.3 < dl_site_ts_order_clean['std_2'],'std_2'] = dl_site_ts_order_clean['mean_2']*0.3

dl_site_ts_order_clean.loc[(dl_site_ts_order_clean['median_2'] > dl_site_ts_order_clean['mean_2']) & 
#                           (dl_site_ts_order_clean['mean']*0.5 <= dl_site_ts_order_clean['std']) & 
                          (dl_site_ts_order_clean['real_pay_amount'] < dl_site_ts_order_clean['mean_2']-dl_site_ts_order_clean['std_2']),'delete_flag_2'] = 1

dl_site_ts_order_clean.loc[(dl_site_ts_order_clean['median_2'] < dl_site_ts_order_clean['mean_2']) & 
#                           (dl_site_ts_order_clean['mean']*0.5 <= dl_site_ts_order_clean['std']) & 
                          (dl_site_ts_order_clean['real_pay_amount'] > dl_site_ts_order_clean['mean_2']+dl_site_ts_order_clean['std_2']),'delete_flag_2'] = 1

dl_site_ts_order_clean.loc[(dl_site_ts_order_clean['median_2'] > dl_site_ts_order_clean['mean_2']) & 
#                           (dl_site_ts_order_clean['mean']*0.5 <= dl_site_ts_order_clean['std']) & 
                          (dl_site_ts_order_clean['real_pay_amount'] < dl_site_ts_order_clean['mean_2']-dl_site_ts_order_clean['std_2']),'real_pay_amount'] = dl_site_ts_order_clean['mean_2']-dl_site_ts_order_clean['std_2']

dl_site_ts_order_clean.loc[(dl_site_ts_order_clean['median_2'] < dl_site_ts_order_clean['mean_2']) & 
#                           (dl_site_ts_order_clean['mean']*0.5 <= dl_site_ts_order_clean['std']) & 
                          (dl_site_ts_order_clean['real_pay_amount'] > dl_site_ts_order_clean['mean_2']+dl_site_ts_order_clean['std_2']),'real_pay_amount'] = dl_site_ts_order_clean['mean_2']+dl_site_ts_order_clean['std_2']

# %%
## 保存处理后的数据
dl_site_ts_order_clean[['car_id','real_pay_amount','delete_flag','delete_flag_1','delete_flag_2']].to_csv(curr_dir+"dl_site_ts_order_clean_"+computer_year+"_yh01.csv")

# %%
print(dl_site_ts_order_clean.loc[(dl_site_ts_order_clean['delete_flag'] == 1)].shape)
print(dl_site_ts_order_clean.loc[(dl_site_ts_order_clean['delete_flag_1'] == 1)].shape)
print(dl_site_ts_order_clean.loc[(dl_site_ts_order_clean['delete_flag_2'] == 1)].shape)
# Out:
# (957812, 32)
# (1194801, 32)
# (1339102, 32)
