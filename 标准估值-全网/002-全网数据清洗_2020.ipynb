# %%
# -*- coding: utf-8 -*-
import warnings
warnings.filterwarnings('ignore')
import logging
import datetime

import csv, math
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.utils import shuffle
from sklearn.externals import joblib
from sklearn.preprocessing import OneHotEncoder
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import GradientBoostingRegressor

from dayu.hooks.oss_hook import OSSHook
from dayu.hooks.hive_server_hook import HiveServerHook
from dayu.hooks.hive_cli_hook import HiveCliHook

def split_table_name(datain):
    new_cols = []
    for column in datain.columns:
        if(len(column.split('.'))<2):
            return datain
        tb_name, col_name = column.split('.')
        new_cols.append((column, col_name))
    datain = datain.rename(columns=dict(new_cols))
    return datain

def read_from_hive2(output_file_name,insql,dtype):
    filename = output_file_name
    filepath = curr_dir+filename
    hive = HiveServerHook("warehouse_hive")
    hive.to_csv(insql,filepath , delimiter=',',lineterminator='\n', output_header=True)
    outdata = pd.read_csv(filepath, header=0,dtype=dtype)
    # 去除列名中带有的表名
#     outdata = split_table_name(outdata)
    return outdata

## 计算时间差
def date_time_sub(startTime,endTime,date_format):
    try:
        startTime= datetime.datetime.strptime(startTime,date_format)
        endTime= datetime.datetime.strptime(endTime,date_format)
        return (endTime - startTime).days
    except:
        pass

    # 计算车辆当前保值率
def computer_with_license_month(tar):
    try:
        license_month = tar['license_month']
        if(license_month<=12):
            #tar['keep_value'] = tar['year_1']
            return tar['year_1']
        else:
            year = license_month//12
            #当前年保值率
            keep_max = tar["year_"+str(int(year))]
            #下一年的保值率
            keep_min = tar["year_"+str(int(year+1))]

            #相比于上一年，已经过了几个月
            mon = license_month-12*year
            tem = (keep_max-keep_min)/12

            #tar['keep_value'] = round(keep_max - tem*mon, 4)
            return round(keep_max - tem*mon, 4)
    except:
        return tar["year_16"]

class Logger:       
    def __init__(self, logName, logFile):
        self._logger = logging.getLogger(logName)
        handler = logging.FileHandler(logFile)
        formatter = logging.Formatter('%(asctime)s ********* %(message)s')
        handler.setFormatter(formatter)
        self._logger.addHandler(handler)
        self._logger.setLevel(logging.INFO)

    def log(self, msg):
        if self._logger is not None:
            self._logger.info(msg)


pd.set_option('display.max_columns', 500)
curr_dir = '/home/souche/qiongjiu/hgc/'

curr_date=str(datetime.datetime.now())[0:10]
hive_cli = HiveCliHook("warehouse_hive")

logger = Logger('model_service','./log/accurate_valuation_cyp_run_log.log')
logger.log("程序启动.............")
## 设定需要计算的年
computer_year = '2020'
# Out:
# [2021-01-07 15:37:03,740] {<ipython-input-30-28c4b78419c8>:84} INFO - 程序启动.............

# %%
sql_info ="""
select * 
from (
    SELECT
        car_id,
        brand_name,
        model_name,
        a_province_name,
        model_code,
        substr(publish_time,1,4)  pay_year,
        substr(license_time,1,4) license_year,
        second_price/10000 real_pay_amount,
        a_province_name,
        mileage,
        row_number() over(partition by model_code,mileage,license_time,a_province_name order by publish_time desc) num 
    FROM
        dl_outrs.dl_vehicle_data_scavenger_ipbl_t_reptile_car_dd
    WHERE
        ds = date_sub('"""+curr_date+"""',1) 
        and second_price/10000 >= 0.3    
        and second_price/10000 < 300 
        and mileage/10000 > 0     
        and mileage/10000 < 100 
        and site not in ('51','renrenche') 
        and substr(publish_time,0,4) in ('"""+computer_year+"""')
) t1
where t1.num = 1 
"""
dtype={'city_code':str}
dl_site_ts_order_clean = read_from_hive2('dl_site_ts_order_clean',sql_info,dtype)

db_columns = []
for col in dl_site_ts_order_clean.columns:
    if len(col.split('.')) > 1:
        db_columns.append(col.split('.')[1])

    else:
        db_columns.append(col)

dl_site_ts_order_clean.columns = db_columns 
logger.log("读取数据完成.............")
# Out:
# [2021-01-07 15:37:05,880] {hiveserver2:138} INFO - Using database default as default
# [2021-01-07 15:37:06,018] {hive_server_hook:112} INFO - Running query:
# select *
# from (
#     SELECT
#         car_id,
#         brand_name,
#         model_name,
#         a_province_name,
#         model_code,
#         substr(publish_time,1,4)  pay_year,
#         substr(license_time,1,4) license_year,
#         second_price/10000 real_pay_amount,
#         a_province_name,
#         mileage,
#         row_number() over(partition by model_code,mileage,license_time,a_province_name order by publish_time desc) num
#     FROM
#         dl_outrs.dl_vehicle_data_scavenger_ipbl_t_reptile_car_dd
#     WHERE
#         ds = date_sub('2021-01-07',1)
#         and second_price/10000 >= 0.3
#         and second_price/10000 < 300
#         and mileage/10000 > 0
#         and mileage/10000 < 100
#         and site not in ('51','renrenche')
#         and substr(publish_time,0,4) in ('2020')
# ) t1
# where t1.num = 1
#
# [2021-01-07 15:38:07,638] {hive_server_hook:162} INFO - Written 10000 rows so far.
# [2021-01-07 15:38:08,062] {hive_server_hook:162} INFO - Written 20000 rows so far.
# [2021-01-07 15:38:08,492] {hive_server_hook:162} INFO - Written 30000 rows so far.
# [2021-01-07 15:38:08,916] {hive_server_hook:162} INFO - Written 40000 rows so far.
# [2021-01-07 15:38:09,317] {hive_server_hook:162} INFO - Written 50000 rows so far.
# [2021-01-07 15:38:09,734] {hive_server_hook:162} INFO - Written 60000 rows so far.
# [2021-01-07 15:38:10,156] {hive_server_hook:162} INFO - Written 70000 rows so far.
# [2021-01-07 15:38:10,597] {hive_server_hook:162} INFO - Written 80000 rows so far.
# [2021-01-07 15:38:11,003] {hive_server_hook:162} INFO - Written 90000 rows so far.
# [2021-01-07 15:38:11,419] {hive_server_hook:162} INFO - Written 100000 rows so far.
# [2021-01-07 15:38:11,853] {hive_server_hook:162} INFO - Written 110000 rows so far.
# [2021-01-07 15:38:12,286] {hive_server_hook:162} INFO - Written 120000 rows so far.
# [2021-01-07 15:38:12,689] {hive_server_hook:162} INFO - Written 130000 rows so far.
# [2021-01-07 15:38:13,114] {hive_server_hook:162} INFO - Written 140000 rows so far.
# [2021-01-07 15:38:13,538] {hive_server_hook:162} INFO - Written 150000 rows so far.
# [2021-01-07 15:38:13,977] {hive_server_hook:162} INFO - Written 160000 rows so far.
# [2021-01-07 15:38:14,401] {hive_server_hook:162} INFO - Written 170000 rows so far.
# [2021-01-07 15:38:14,796] {hive_server_hook:162} INFO - Written 180000 rows so far.
# [2021-01-07 15:38:15,223] {hive_server_hook:162} INFO - Written 190000 rows so far.
# [2021-01-07 15:38:15,657] {hive_server_hook:162} INFO - Written 200000 rows so far.
# [2021-01-07 15:38:16,081] {hive_server_hook:162} INFO - Written 210000 rows so far.
# [2021-01-07 15:38:16,473] {hive_server_hook:162} INFO - Written 220000 rows so far.
# [2021-01-07 15:38:16,898] {hive_server_hook:162} INFO - Written 230000 rows so far.
# [2021-01-07 15:38:17,336] {hive_server_hook:162} INFO - Written 240000 rows so far.
# [2021-01-07 15:38:17,762] {hive_server_hook:162} INFO - Written 250000 rows so far.
# [2021-01-07 15:38:18,157] {hive_server_hook:162} INFO - Written 260000 rows so far.
# [2021-01-07 15:38:18,584] {hive_server_hook:162} INFO - Written 270000 rows so far.
# [2021-01-07 15:38:19,062] {hive_server_hook:162} INFO - Written 280000 rows so far.
# [2021-01-07 15:38:19,503] {hive_server_hook:162} INFO - Written 290000 rows so far.
# [2021-01-07 15:38:19,896] {hive_server_hook:162} INFO - Written 300000 rows so far.
# [2021-01-07 15:38:20,326] {hive_server_hook:162} INFO - Written 310000 rows so far.
# [2021-01-07 15:38:20,779] {hive_server_hook:162} INFO - Written 320000 rows so far.
# [2021-01-07 15:38:21,216] {hive_server_hook:162} INFO - Written 330000 rows so far.
# [2021-01-07 15:38:21,639] {hive_server_hook:162} INFO - Written 340000 rows so far.
# [2021-01-07 15:38:22,042] {hive_server_hook:162} INFO - Written 350000 rows so far.
# [2021-01-07 15:38:22,468] {hive_server_hook:162} INFO - Written 360000 rows so far.
# [2021-01-07 15:38:22,897] {hive_server_hook:162} INFO - Written 370000 rows so far.
# [2021-01-07 15:38:23,328] {hive_server_hook:162} INFO - Written 380000 rows so far.
# [2021-01-07 15:38:23,724] {hive_server_hook:162} INFO - Written 390000 rows so far.
# [2021-01-07 15:38:24,153] {hive_server_hook:162} INFO - Written 400000 rows so far.
# [2021-01-07 15:38:24,587] {hive_server_hook:162} INFO - Written 410000 rows so far.
# [2021-01-07 15:38:25,029] {hive_server_hook:162} INFO - Written 420000 rows so far.
# [2021-01-07 15:38:25,434] {hive_server_hook:162} INFO - Written 430000 rows so far.
# [2021-01-07 15:38:25,862] {hive_server_hook:162} INFO - Written 440000 rows so far.
# [2021-01-07 15:38:26,287] {hive_server_hook:162} INFO - Written 450000 rows so far.
# [2021-01-07 15:38:26,716] {hive_server_hook:162} INFO - Written 460000 rows so far.
# [2021-01-07 15:38:27,115] {hive_server_hook:162} INFO - Written 470000 rows so far.
# [2021-01-07 15:38:27,543] {hive_server_hook:162} INFO - Written 480000 rows so far.
# [2021-01-07 15:38:27,970] {hive_server_hook:162} INFO - Written 490000 rows so far.
# [2021-01-07 15:38:28,402] {hive_server_hook:162} INFO - Written 500000 rows so far.
# [2021-01-07 15:38:28,839] {hive_server_hook:162} INFO - Written 510000 rows so far.
# [2021-01-07 15:38:29,234] {hive_server_hook:162} INFO - Written 520000 rows so far.
# [2021-01-07 15:38:29,667] {hive_server_hook:162} INFO - Written 530000 rows so far.
# [2021-01-07 15:38:30,095] {hive_server_hook:162} INFO - Written 540000 rows so far.
# [2021-01-07 15:38:30,542] {hive_server_hook:162} INFO - Written 550000 rows so far.
# [2021-01-07 15:38:30,946] {hive_server_hook:162} INFO - Written 560000 rows so far.
# [2021-01-07 15:38:31,374] {hive_server_hook:162} INFO - Written 570000 rows so far.
# [2021-01-07 15:38:31,811] {hive_server_hook:162} INFO - Written 580000 rows so far.
# [2021-01-07 15:38:32,250] {hive_server_hook:162} INFO - Written 590000 rows so far.
# [2021-01-07 15:38:32,645] {hive_server_hook:162} INFO - Written 600000 rows so far.
# [2021-01-07 15:38:33,074] {hive_server_hook:162} INFO - Written 610000 rows so far.
# [2021-01-07 15:38:33,543] {hive_server_hook:162} INFO - Written 620000 rows so far.
# [2021-01-07 15:38:33,965] {hive_server_hook:162} INFO - Written 630000 rows so far.
# [2021-01-07 15:38:34,371] {hive_server_hook:162} INFO - Written 640000 rows so far.
# [2021-01-07 15:38:34,801] {hive_server_hook:162} INFO - Written 650000 rows so far.
# [2021-01-07 15:38:35,225] {hive_server_hook:162} INFO - Written 660000 rows so far.
# [2021-01-07 15:38:35,644] {hive_server_hook:162} INFO - Written 670000 rows so far.
# [2021-01-07 15:38:36,069] {hive_server_hook:162} INFO - Written 680000 rows so far.
# [2021-01-07 15:38:36,481] {hive_server_hook:162} INFO - Written 690000 rows so far.
# [2021-01-07 15:38:36,909] {hive_server_hook:162} INFO - Written 700000 rows so far.
# [2021-01-07 15:38:37,333] {hive_server_hook:162} INFO - Written 710000 rows so far.
# [2021-01-07 15:38:37,768] {hive_server_hook:162} INFO - Written 720000 rows so far.
# [2021-01-07 15:38:38,169] {hive_server_hook:162} INFO - Written 730000 rows so far.
# [2021-01-07 15:38:38,589] {hive_server_hook:162} INFO - Written 740000 rows so far.
# [2021-01-07 15:38:39,031] {hive_server_hook:162} INFO - Written 750000 rows so far.
# [2021-01-07 15:38:39,454] {hive_server_hook:162} INFO - Written 760000 rows so far.
# [2021-01-07 15:38:39,853] {hive_server_hook:162} INFO - Written 770000 rows so far.
# [2021-01-07 15:38:40,298] {hive_server_hook:162} INFO - Written 780000 rows so far.
# [2021-01-07 15:38:40,731] {hive_server_hook:162} INFO - Written 790000 rows so far.
# [2021-01-07 15:38:41,159] {hive_server_hook:162} INFO - Written 800000 rows so far.
# [2021-01-07 15:38:41,584] {hive_server_hook:162} INFO - Written 810000 rows so far.
# [2021-01-07 15:38:41,980] {hive_server_hook:162} INFO - Written 820000 rows so far.
# [2021-01-07 15:38:42,425] {hive_server_hook:162} INFO - Written 830000 rows so far.
# [2021-01-07 15:38:42,853] {hive_server_hook:162} INFO - Written 840000 rows so far.
# [2021-01-07 15:38:43,306] {hive_server_hook:162} INFO - Written 850000 rows so far.
# [2021-01-07 15:38:43,703] {hive_server_hook:162} INFO - Written 860000 rows so far.
# [2021-01-07 15:38:44,133] {hive_server_hook:162} INFO - Written 870000 rows so far.
# [2021-01-07 15:38:44,556] {hive_server_hook:162} INFO - Written 880000 rows so far.
# [2021-01-07 15:38:44,980] {hive_server_hook:162} INFO - Written 890000 rows so far.
# [2021-01-07 15:38:45,380] {hive_server_hook:162} INFO - Written 900000 rows so far.
# [2021-01-07 15:38:45,816] {hive_server_hook:162} INFO - Written 910000 rows so far.
# [2021-01-07 15:38:46,275] {hive_server_hook:162} INFO - Written 920000 rows so far.
# [2021-01-07 15:38:46,720] {hive_server_hook:162} INFO - Written 930000 rows so far.
# [2021-01-07 15:38:47,116] {hive_server_hook:162} INFO - Written 940000 rows so far.
# [2021-01-07 15:38:47,545] {hive_server_hook:162} INFO - Written 950000 rows so far.
# [2021-01-07 15:38:47,970] {hive_server_hook:162} INFO - Written 960000 rows so far.
# [2021-01-07 15:38:48,401] {hive_server_hook:162} INFO - Written 970000 rows so far.
# [2021-01-07 15:38:48,824] {hive_server_hook:162} INFO - Written 980000 rows so far.
# [2021-01-07 15:38:49,221] {hive_server_hook:162} INFO - Written 990000 rows so far.
# [2021-01-07 15:38:49,645] {hive_server_hook:162} INFO - Written 1000000 rows so far.
# [2021-01-07 15:38:50,074] {hive_server_hook:162} INFO - Written 1010000 rows so far.
# [2021-01-07 15:38:50,517] {hive_server_hook:162} INFO - Written 1020000 rows so far.
# [2021-01-07 15:38:50,922] {hive_server_hook:162} INFO - Written 1030000 rows so far.
# [2021-01-07 15:38:51,346] {hive_server_hook:162} INFO - Written 1040000 rows so far.
# [2021-01-07 15:38:51,768] {hive_server_hook:162} INFO - Written 1050000 rows so far.
# [2021-01-07 15:38:52,200] {hive_server_hook:162} INFO - Written 1060000 rows so far.
# [2021-01-07 15:38:52,605] {hive_server_hook:162} INFO - Written 1070000 rows so far.
# [2021-01-07 15:38:53,031] {hive_server_hook:162} INFO - Written 1080000 rows so far.
# [2021-01-07 15:38:53,453] {hive_server_hook:162} INFO - Written 1090000 rows so far.
# [2021-01-07 15:38:53,886] {hive_server_hook:162} INFO - Written 1100000 rows so far.
# [2021-01-07 15:38:54,306] {hive_server_hook:162} INFO - Written 1110000 rows so far.
# [2021-01-07 15:38:54,732] {hive_server_hook:162} INFO - Written 1120000 rows so far.
# [2021-01-07 15:38:55,166] {hive_server_hook:162} INFO - Written 1130000 rows so far.
# [2021-01-07 15:38:55,618] {hive_server_hook:162} INFO - Written 1140000 rows so far.
# [2021-01-07 15:38:56,043] {hive_server_hook:162} INFO - Written 1150000 rows so far.
# [2021-01-07 15:38:56,441] {hive_server_hook:162} INFO - Written 1160000 rows so far.
# [2021-01-07 15:38:56,875] {hive_server_hook:162} INFO - Written 1170000 rows so far.
# [2021-01-07 15:38:57,305] {hive_server_hook:162} INFO - Written 1180000 rows so far.
# [2021-01-07 15:38:57,731] {hive_server_hook:162} INFO - Written 1190000 rows so far.
# [2021-01-07 15:38:58,141] {hive_server_hook:162} INFO - Written 1200000 rows so far.
# [2021-01-07 15:38:58,570] {hive_server_hook:162} INFO - Written 1210000 rows so far.
# [2021-01-07 15:38:59,011] {hive_server_hook:162} INFO - Written 1220000 rows so far.
# [2021-01-07 15:38:59,448] {hive_server_hook:162} INFO - Written 1230000 rows so far.
# [2021-01-07 15:38:59,845] {hive_server_hook:162} INFO - Written 1240000 rows so far.
# [2021-01-07 15:39:00,293] {hive_server_hook:162} INFO - Written 1250000 rows so far.
# [2021-01-07 15:39:00,726] {hive_server_hook:162} INFO - Written 1260000 rows so far.
# [2021-01-07 15:39:01,167] {hive_server_hook:162} INFO - Written 1270000 rows so far.
# [2021-01-07 15:39:01,576] {hive_server_hook:162} INFO - Written 1280000 rows so far.
# [2021-01-07 15:39:02,010] {hive_server_hook:162} INFO - Written 1290000 rows so far.
# [2021-01-07 15:39:02,443] {hive_server_hook:162} INFO - Written 1300000 rows so far.
# [2021-01-07 15:39:02,880] {hive_server_hook:162} INFO - Written 1310000 rows so far.
# [2021-01-07 15:39:03,310] {hive_server_hook:162} INFO - Written 1320000 rows so far.
# [2021-01-07 15:39:03,708] {hive_server_hook:162} INFO - Written 1330000 rows so far.
# [2021-01-07 15:39:04,128] {hive_server_hook:162} INFO - Written 1340000 rows so far.
# [2021-01-07 15:39:04,553] {hive_server_hook:162} INFO - Written 1350000 rows so far.
# [2021-01-07 15:39:04,979] {hive_server_hook:162} INFO - Written 1360000 rows so far.
# [2021-01-07 15:39:05,381] {hive_server_hook:162} INFO - Written 1370000 rows so far.
# [2021-01-07 15:39:05,809] {hive_server_hook:162} INFO - Written 1380000 rows so far.
# [2021-01-07 15:39:06,245] {hive_server_hook:162} INFO - Written 1390000 rows so far.
# [2021-01-07 15:39:06,677] {hive_server_hook:162} INFO - Written 1400000 rows so far.
# [2021-01-07 15:39:07,081] {hive_server_hook:162} INFO - Written 1410000 rows so far.
# [2021-01-07 15:39:07,516] {hive_server_hook:162} INFO - Written 1420000 rows so far.
# [2021-01-07 15:39:07,973] {hive_server_hook:162} INFO - Written 1430000 rows so far.
# [2021-01-07 15:39:08,400] {hive_server_hook:162} INFO - Written 1440000 rows so far.
# [2021-01-07 15:39:08,820] {hive_server_hook:162} INFO - Written 1450000 rows so far.
# [2021-01-07 15:39:09,222] {hive_server_hook:162} INFO - Written 1460000 rows so far.
# [2021-01-07 15:39:09,644] {hive_server_hook:162} INFO - Written 1470000 rows so far.
# [2021-01-07 15:39:10,083] {hive_server_hook:162} INFO - Written 1480000 rows so far.
# [2021-01-07 15:39:10,534] {hive_server_hook:162} INFO - Written 1490000 rows so far.
# [2021-01-07 15:39:10,938] {hive_server_hook:162} INFO - Written 1500000 rows so far.
# [2021-01-07 15:39:11,369] {hive_server_hook:162} INFO - Written 1510000 rows so far.
# [2021-01-07 15:39:11,789] {hive_server_hook:162} INFO - Written 1520000 rows so far.
# [2021-01-07 15:39:12,213] {hive_server_hook:162} INFO - Written 1530000 rows so far.
# [2021-01-07 15:39:12,606] {hive_server_hook:162} INFO - Written 1540000 rows so far.
# [2021-01-07 15:39:13,044] {hive_server_hook:162} INFO - Written 1550000 rows so far.
# [2021-01-07 15:39:13,471] {hive_server_hook:162} INFO - Written 1560000 rows so far.
# [2021-01-07 15:39:13,914] {hive_server_hook:162} INFO - Written 1570000 rows so far.
# [2021-01-07 15:39:14,316] {hive_server_hook:162} INFO - Written 1580000 rows so far.
# [2021-01-07 15:39:14,742] {hive_server_hook:162} INFO - Written 1590000 rows so far.
# [2021-01-07 15:39:15,182] {hive_server_hook:162} INFO - Written 1600000 rows so far.
# [2021-01-07 15:39:15,611] {hive_server_hook:162} INFO - Written 1610000 rows so far.
# [2021-01-07 15:39:16,044] {hive_server_hook:162} INFO - Written 1620000 rows so far.
# [2021-01-07 15:39:16,459] {hive_server_hook:162} INFO - Written 1630000 rows so far.
# [2021-01-07 15:39:16,894] {hive_server_hook:162} INFO - Written 1640000 rows so far.
# [2021-01-07 15:39:17,333] {hive_server_hook:162} INFO - Written 1650000 rows so far.
# [2021-01-07 15:39:17,762] {hive_server_hook:162} INFO - Written 1660000 rows so far.
# [2021-01-07 15:39:18,165] {hive_server_hook:162} INFO - Written 1670000 rows so far.
# [2021-01-07 15:39:18,589] {hive_server_hook:162} INFO - Written 1680000 rows so far.
# [2021-01-07 15:39:19,046] {hive_server_hook:162} INFO - Written 1690000 rows so far.
# [2021-01-07 15:39:19,469] {hive_server_hook:162} INFO - Written 1700000 rows so far.
# [2021-01-07 15:39:19,871] {hive_server_hook:162} INFO - Written 1710000 rows so far.
# [2021-01-07 15:39:20,304] {hive_server_hook:162} INFO - Written 1720000 rows so far.
# [2021-01-07 15:39:20,744] {hive_server_hook:162} INFO - Written 1730000 rows so far.
# [2021-01-07 15:39:21,175] {hive_server_hook:162} INFO - Written 1740000 rows so far.
# [2021-01-07 15:39:21,593] {hive_server_hook:162} INFO - Written 1750000 rows so far.
# [2021-01-07 15:39:22,011] {hive_server_hook:162} INFO - Written 1760000 rows so far.
# [2021-01-07 15:39:22,433] {hive_server_hook:162} INFO - Written 1770000 rows so far.
# [2021-01-07 15:39:22,857] {hive_server_hook:162} INFO - Written 1780000 rows so far.
# [2021-01-07 15:39:23,289] {hive_server_hook:162} INFO - Written 1790000 rows so far.
# [2021-01-07 15:39:23,690] {hive_server_hook:162} INFO - Written 1800000 rows so far.
# [2021-01-07 15:39:24,113] {hive_server_hook:162} INFO - Written 1810000 rows so far.
# [2021-01-07 15:39:24,545] {hive_server_hook:162} INFO - Written 1820000 rows so far.
# [2021-01-07 15:39:24,970] {hive_server_hook:162} INFO - Written 1830000 rows so far.
# [2021-01-07 15:39:25,376] {hive_server_hook:162} INFO - Written 1840000 rows so far.
# [2021-01-07 15:39:25,804] {hive_server_hook:162} INFO - Written 1850000 rows so far.
# [2021-01-07 15:39:26,230] {hive_server_hook:162} INFO - Written 1860000 rows so far.
# [2021-01-07 15:39:26,664] {hive_server_hook:162} INFO - Written 1870000 rows so far.
# [2021-01-07 15:39:27,062] {hive_server_hook:162} INFO - Written 1880000 rows so far.
# [2021-01-07 15:39:27,492] {hive_server_hook:162} INFO - Written 1890000 rows so far.
# [2021-01-07 15:39:27,917] {hive_server_hook:162} INFO - Written 1900000 rows so far.
# [2021-01-07 15:39:28,345] {hive_server_hook:162} INFO - Written 1910000 rows so far.
# [2021-01-07 15:39:28,758] {hive_server_hook:162} INFO - Written 1920000 rows so far.
# [2021-01-07 15:39:29,219] {hive_server_hook:162} INFO - Written 1930000 rows so far.
# [2021-01-07 15:39:29,647] {hive_server_hook:162} INFO - Written 1940000 rows so far.
# [2021-01-07 15:39:30,070] {hive_server_hook:162} INFO - Written 1950000 rows so far.
# [2021-01-07 15:39:30,514] {hive_server_hook:162} INFO - Written 1960000 rows so far.
# [2021-01-07 15:39:30,919] {hive_server_hook:162} INFO - Written 1970000 rows so far.
# [2021-01-07 15:39:31,354] {hive_server_hook:162} INFO - Written 1980000 rows so far.
# [2021-01-07 15:39:31,782] {hive_server_hook:162} INFO - Written 1990000 rows so far.
# [2021-01-07 15:39:32,208] {hive_server_hook:162} INFO - Written 2000000 rows so far.
# [2021-01-07 15:39:32,613] {hive_server_hook:162} INFO - Written 2010000 rows so far.
# [2021-01-07 15:39:33,035] {hive_server_hook:162} INFO - Written 2020000 rows so far.
# [2021-01-07 15:39:33,457] {hive_server_hook:162} INFO - Written 2030000 rows so far.
# [2021-01-07 15:39:33,881] {hive_server_hook:162} INFO - Written 2040000 rows so far.
# [2021-01-07 15:39:34,283] {hive_server_hook:162} INFO - Written 2050000 rows so far.
# [2021-01-07 15:39:34,714] {hive_server_hook:162} INFO - Written 2060000 rows so far.
# [2021-01-07 15:39:35,152] {hive_server_hook:162} INFO - Written 2070000 rows so far.
# [2021-01-07 15:39:35,583] {hive_server_hook:162} INFO - Written 2080000 rows so far.
# [2021-01-07 15:39:36,010] {hive_server_hook:162} INFO - Written 2090000 rows so far.
# [2021-01-07 15:39:36,426] {hive_server_hook:162} INFO - Written 2100000 rows so far.
# [2021-01-07 15:39:36,851] {hive_server_hook:162} INFO - Written 2110000 rows so far.
# [2021-01-07 15:39:37,277] {hive_server_hook:162} INFO - Written 2120000 rows so far.
# [2021-01-07 15:39:37,704] {hive_server_hook:162} INFO - Written 2130000 rows so far.
# [2021-01-07 15:39:38,099] {hive_server_hook:162} INFO - Written 2140000 rows so far.
# [2021-01-07 15:39:38,524] {hive_server_hook:162} INFO - Written 2150000 rows so far.
# [2021-01-07 15:39:38,959] {hive_server_hook:162} INFO - Written 2160000 rows so far.
# [2021-01-07 15:39:39,465] {hive_server_hook:162} INFO - Written 2170000 rows so far.
# [2021-01-07 15:39:39,870] {hive_server_hook:162} INFO - Written 2180000 rows so far.
# [2021-01-07 15:39:40,302] {hive_server_hook:162} INFO - Written 2190000 rows so far.
# [2021-01-07 15:39:40,730] {hive_server_hook:162} INFO - Written 2200000 rows so far.
# [2021-01-07 15:39:41,158] {hive_server_hook:162} INFO - Written 2210000 rows so far.
# [2021-01-07 15:39:41,563] {hive_server_hook:162} INFO - Written 2220000 rows so far.
# [2021-01-07 15:39:41,992] {hive_server_hook:162} INFO - Written 2230000 rows so far.
# [2021-01-07 15:39:42,432] {hive_server_hook:162} INFO - Written 2240000 rows so far.
# [2021-01-07 15:39:42,853] {hive_server_hook:162} INFO - Written 2250000 rows so far.
# [2021-01-07 15:39:43,289] {hive_server_hook:162} INFO - Written 2260000 rows so far.
# [2021-01-07 15:39:43,686] {hive_server_hook:162} INFO - Written 2270000 rows so far.
# [2021-01-07 15:39:44,110] {hive_server_hook:162} INFO - Written 2280000 rows so far.
# [2021-01-07 15:39:44,532] {hive_server_hook:162} INFO - Written 2290000 rows so far.
# [2021-01-07 15:39:44,963] {hive_server_hook:162} INFO - Written 2300000 rows so far.
# [2021-01-07 15:39:45,370] {hive_server_hook:162} INFO - Written 2310000 rows so far.
# [2021-01-07 15:39:45,797] {hive_server_hook:162} INFO - Written 2320000 rows so far.
# [2021-01-07 15:39:46,239] {hive_server_hook:162} INFO - Written 2330000 rows so far.
# [2021-01-07 15:39:46,673] {hive_server_hook:162} INFO - Written 2340000 rows so far.
# [2021-01-07 15:39:47,077] {hive_server_hook:162} INFO - Written 2350000 rows so far.
# [2021-01-07 15:39:47,503] {hive_server_hook:162} INFO - Written 2360000 rows so far.
# [2021-01-07 15:39:47,925] {hive_server_hook:162} INFO - Written 2370000 rows so far.
# [2021-01-07 15:39:48,347] {hive_server_hook:162} INFO - Written 2380000 rows so far.
# [2021-01-07 15:39:48,748] {hive_server_hook:162} INFO - Written 2390000 rows so far.
# [2021-01-07 15:39:49,173] {hive_server_hook:162} INFO - Written 2400000 rows so far.
# [2021-01-07 15:39:49,599] {hive_server_hook:162} INFO - Written 2410000 rows so far.
# [2021-01-07 15:39:50,030] {hive_server_hook:162} INFO - Written 2420000 rows so far.
# [2021-01-07 15:39:50,509] {hive_server_hook:162} INFO - Written 2430000 rows so far.
# [2021-01-07 15:39:50,906] {hive_server_hook:162} INFO - Written 2440000 rows so far.
# [2021-01-07 15:39:51,337] {hive_server_hook:162} INFO - Written 2450000 rows so far.
# [2021-01-07 15:39:51,767] {hive_server_hook:162} INFO - Written 2460000 rows so far.
# [2021-01-07 15:39:52,193] {hive_server_hook:162} INFO - Written 2470000 rows so far.
# [2021-01-07 15:39:52,587] {hive_server_hook:162} INFO - Written 2480000 rows so far.
# [2021-01-07 15:39:53,012] {hive_server_hook:162} INFO - Written 2490000 rows so far.
# [2021-01-07 15:39:53,436] {hive_server_hook:162} INFO - Written 2500000 rows so far.
# [2021-01-07 15:39:53,855] {hive_server_hook:162} INFO - Written 2510000 rows so far.
# [2021-01-07 15:39:54,265] {hive_server_hook:162} INFO - Written 2520000 rows so far.
# [2021-01-07 15:39:54,690] {hive_server_hook:162} INFO - Written 2530000 rows so far.
# [2021-01-07 15:39:55,130] {hive_server_hook:162} INFO - Written 2540000 rows so far.
# [2021-01-07 15:39:55,558] {hive_server_hook:162} INFO - Written 2550000 rows so far.
# [2021-01-07 15:39:55,951] {hive_server_hook:162} INFO - Written 2560000 rows so far.
# [2021-01-07 15:39:56,393] {hive_server_hook:162} INFO - Written 2570000 rows so far.
# [2021-01-07 15:39:56,826] {hive_server_hook:162} INFO - Written 2580000 rows so far.
# [2021-01-07 15:39:57,244] {hive_server_hook:162} INFO - Written 2590000 rows so far.
# [2021-01-07 15:39:57,680] {hive_server_hook:162} INFO - Written 2600000 rows so far.
# [2021-01-07 15:39:58,083] {hive_server_hook:162} INFO - Written 2610000 rows so far.
# [2021-01-07 15:39:58,512] {hive_server_hook:162} INFO - Written 2620000 rows so far.
# [2021-01-07 15:39:58,938] {hive_server_hook:162} INFO - Written 2630000 rows so far.
# [2021-01-07 15:39:59,361] {hive_server_hook:162} INFO - Written 2640000 rows so far.
# [2021-01-07 15:39:59,759] {hive_server_hook:162} INFO - Written 2650000 rows so far.
# [2021-01-07 15:40:00,192] {hive_server_hook:162} INFO - Written 2660000 rows so far.
# [2021-01-07 15:40:00,626] {hive_server_hook:162} INFO - Written 2670000 rows so far.
# [2021-01-07 15:40:01,058] {hive_server_hook:162} INFO - Written 2680000 rows so far.
# [2021-01-07 15:40:01,470] {hive_server_hook:162} INFO - Written 2690000 rows so far.
# [2021-01-07 15:40:01,939] {hive_server_hook:162} INFO - Written 2700000 rows so far.
# [2021-01-07 15:40:02,383] {hive_server_hook:162} INFO - Written 2710000 rows so far.
# [2021-01-07 15:40:02,820] {hive_server_hook:162} INFO - Written 2720000 rows so far.
# [2021-01-07 15:40:03,261] {hive_server_hook:162} INFO - Written 2730000 rows so far.
# [2021-01-07 15:40:03,670] {hive_server_hook:162} INFO - Written 2740000 rows so far.
# [2021-01-07 15:40:04,102] {hive_server_hook:162} INFO - Written 2750000 rows so far.
# [2021-01-07 15:40:04,536] {hive_server_hook:162} INFO - Written 2760000 rows so far.
# [2021-01-07 15:40:04,959] {hive_server_hook:162} INFO - Written 2770000 rows so far.
# [2021-01-07 15:40:05,379] {hive_server_hook:162} INFO - Written 2780000 rows so far.
# [2021-01-07 15:40:05,817] {hive_server_hook:162} INFO - Written 2790000 rows so far.
# [2021-01-07 15:40:06,255] {hive_server_hook:162} INFO - Written 2800000 rows so far.
# [2021-01-07 15:40:06,678] {hive_server_hook:162} INFO - Written 2810000 rows so far.
# [2021-01-07 15:40:07,074] {hive_server_hook:162} INFO - Written 2820000 rows so far.
# [2021-01-07 15:40:07,146] {hive_server_hook:162} INFO - Written 2821741 rows so far.
# [2021-01-07 15:40:07,225] {hiveserver2:265} INFO - Closing active operation
# [2021-01-07 15:40:07,266] {hive_server_hook:163} INFO - Done. Loaded a total of 2821741 rows.
# [2021-01-07 15:40:12,263] {<ipython-input-30-28c4b78419c8>:84} INFO - 读取数据完成.............

# %%
## 重命名
dl_site_ts_order_clean = dl_site_ts_order_clean.rename(columns={'license_year':'license_time_year','pay_year':'publish_time_year'})

# %%
## 剔除极大或者极小的峰值
dl_site_ts_order_clean_count = dl_site_ts_order_clean[['model_code','license_time_year','real_pay_amount']].\
groupby(['model_code','license_time_year']).count().reset_index().rename(columns={'real_pay_amount':'count'})

dl_site_ts_order_clean_mean = dl_site_ts_order_clean[['model_code','license_time_year','real_pay_amount']].\
groupby(['model_code','license_time_year']).mean().reset_index().rename(columns={'real_pay_amount':'mean'})

dl_site_ts_order_clean_std = dl_site_ts_order_clean[['model_code','license_time_year','real_pay_amount']].\
groupby(['model_code','license_time_year']).std().reset_index().rename(columns={'real_pay_amount':'std'})

dl_site_ts_order_clean_median = dl_site_ts_order_clean[['model_code','license_time_year','real_pay_amount']].\
groupby(['model_code','license_time_year']).median().reset_index().rename(columns={'real_pay_amount':'median'})

dl_site_ts_order_clean_min = dl_site_ts_order_clean[['model_code','license_time_year','real_pay_amount']].\
groupby(['model_code','license_time_year']).min().reset_index().rename(columns={'real_pay_amount':'min_price'})

dl_site_ts_order_clean_max = dl_site_ts_order_clean[['model_code','license_time_year','real_pay_amount']].\
groupby(['model_code','license_time_year']).max().reset_index().rename(columns={'real_pay_amount':'max_price'})

dl_site_ts_order_clean = pd.merge(dl_site_ts_order_clean,dl_site_ts_order_clean_count,on=['model_code','license_time_year'],how='left')
dl_site_ts_order_clean = pd.merge(dl_site_ts_order_clean,dl_site_ts_order_clean_mean,on=['model_code','license_time_year'],how='left')
dl_site_ts_order_clean = pd.merge(dl_site_ts_order_clean,dl_site_ts_order_clean_std,on=['model_code','license_time_year'],how='left')
dl_site_ts_order_clean = pd.merge(dl_site_ts_order_clean,dl_site_ts_order_clean_min,on=['model_code','license_time_year'],how='left')
dl_site_ts_order_clean = pd.merge(dl_site_ts_order_clean,dl_site_ts_order_clean_max,on=['model_code','license_time_year'],how='left')
dl_site_ts_order_clean = pd.merge(dl_site_ts_order_clean,dl_site_ts_order_clean_median,on=['model_code','license_time_year'],how='left')

## 剔除峰值
dl_site_ts_order_clean.loc[dl_site_ts_order_clean['mean']*0.3 < dl_site_ts_order_clean['std'],'std'] = dl_site_ts_order_clean['mean']*0.3

dl_site_ts_order_clean.loc[(dl_site_ts_order_clean['median'] > dl_site_ts_order_clean['mean']) & 
#                           (dl_site_ts_order_clean['mean']*0.5 <= dl_site_ts_order_clean['std']) & 
                          (dl_site_ts_order_clean['real_pay_amount'] < dl_site_ts_order_clean['mean']-dl_site_ts_order_clean['std']),'delete_flag'] = 1

dl_site_ts_order_clean.loc[(dl_site_ts_order_clean['median'] < dl_site_ts_order_clean['mean']) & 
#                           (dl_site_ts_order_clean['mean']*0.5 <= dl_site_ts_order_clean['std']) & 
                          (dl_site_ts_order_clean['real_pay_amount'] > dl_site_ts_order_clean['mean']+dl_site_ts_order_clean['std']),'delete_flag'] = 1

dl_site_ts_order_clean.loc[(dl_site_ts_order_clean['median'] > dl_site_ts_order_clean['mean']) & 
#                           (dl_site_ts_order_clean['mean']*0.5 <= dl_site_ts_order_clean['std']) & 
                          (dl_site_ts_order_clean['real_pay_amount'] < dl_site_ts_order_clean['mean']-dl_site_ts_order_clean['std']),'real_pay_amount'] = dl_site_ts_order_clean['mean']-dl_site_ts_order_clean['std']

dl_site_ts_order_clean.loc[(dl_site_ts_order_clean['median'] < dl_site_ts_order_clean['mean']) & 
#                           (dl_site_ts_order_clean['mean']*0.5 <= dl_site_ts_order_clean['std']) & 
                          (dl_site_ts_order_clean['real_pay_amount'] > dl_site_ts_order_clean['mean']+dl_site_ts_order_clean['std']),'real_pay_amount'] = dl_site_ts_order_clean['mean']+dl_site_ts_order_clean['std']

# %%
## 剔除极大或者极小的峰值
dl_site_ts_order_clean_count = dl_site_ts_order_clean[['model_code','license_time_year','real_pay_amount']].\
groupby(['model_code','license_time_year']).count().reset_index().rename(columns={'real_pay_amount':'count_1'})

dl_site_ts_order_clean_mean = dl_site_ts_order_clean[['model_code','license_time_year','real_pay_amount']].\
groupby(['model_code','license_time_year']).mean().reset_index().rename(columns={'real_pay_amount':'mean_1'})

dl_site_ts_order_clean_std = dl_site_ts_order_clean[['model_code','license_time_year','real_pay_amount']].\
groupby(['model_code','license_time_year']).std().reset_index().rename(columns={'real_pay_amount':'std_1'})

dl_site_ts_order_clean_median = dl_site_ts_order_clean[['model_code','license_time_year','real_pay_amount']].\
groupby(['model_code','license_time_year']).median().reset_index().rename(columns={'real_pay_amount':'median_1'})

dl_site_ts_order_clean_min = dl_site_ts_order_clean[['model_code','license_time_year','real_pay_amount']].\
groupby(['model_code','license_time_year']).min().reset_index().rename(columns={'real_pay_amount':'min_price_1'})

dl_site_ts_order_clean_max = dl_site_ts_order_clean[['model_code','license_time_year','real_pay_amount']].\
groupby(['model_code','license_time_year']).max().reset_index().rename(columns={'real_pay_amount':'max_price_1'})

dl_site_ts_order_clean = pd.merge(dl_site_ts_order_clean,dl_site_ts_order_clean_count,on=['model_code','license_time_year'],how='left')
dl_site_ts_order_clean = pd.merge(dl_site_ts_order_clean,dl_site_ts_order_clean_mean,on=['model_code','license_time_year'],how='left')
dl_site_ts_order_clean = pd.merge(dl_site_ts_order_clean,dl_site_ts_order_clean_std,on=['model_code','license_time_year'],how='left')
dl_site_ts_order_clean = pd.merge(dl_site_ts_order_clean,dl_site_ts_order_clean_min,on=['model_code','license_time_year'],how='left')
dl_site_ts_order_clean = pd.merge(dl_site_ts_order_clean,dl_site_ts_order_clean_max,on=['model_code','license_time_year'],how='left')
dl_site_ts_order_clean = pd.merge(dl_site_ts_order_clean,dl_site_ts_order_clean_median,on=['model_code','license_time_year'],how='left')

## 剔除峰值
dl_site_ts_order_clean.loc[dl_site_ts_order_clean['mean_1']*0.3 < dl_site_ts_order_clean['std_1'],'std_1'] = dl_site_ts_order_clean['mean_1']*0.3

dl_site_ts_order_clean.loc[(dl_site_ts_order_clean['median_1'] > dl_site_ts_order_clean['mean_1']) & 
#                           (dl_site_ts_order_clean['mean']*0.5 <= dl_site_ts_order_clean['std']) & 
                          (dl_site_ts_order_clean['real_pay_amount'] < dl_site_ts_order_clean['mean_1']-dl_site_ts_order_clean['std_1']),'delete_flag_1'] = 1

dl_site_ts_order_clean.loc[(dl_site_ts_order_clean['median_1'] < dl_site_ts_order_clean['mean_1']) & 
#                           (dl_site_ts_order_clean['mean']*0.5 <= dl_site_ts_order_clean['std']) & 
                          (dl_site_ts_order_clean['real_pay_amount'] > dl_site_ts_order_clean['mean_1']+dl_site_ts_order_clean['std_1']),'delete_flag_1'] = 1

dl_site_ts_order_clean.loc[(dl_site_ts_order_clean['median_1'] > dl_site_ts_order_clean['mean_1']) & 
#                           (dl_site_ts_order_clean['mean']*0.5 <= dl_site_ts_order_clean['std']) & 
                          (dl_site_ts_order_clean['real_pay_amount'] < dl_site_ts_order_clean['mean_1']-dl_site_ts_order_clean['std_1']),'real_pay_amount'] = dl_site_ts_order_clean['mean_1']-dl_site_ts_order_clean['std_1']

dl_site_ts_order_clean.loc[(dl_site_ts_order_clean['median_1'] < dl_site_ts_order_clean['mean_1']) & 
#                           (dl_site_ts_order_clean['mean']*0.5 <= dl_site_ts_order_clean['std']) & 
                          (dl_site_ts_order_clean['real_pay_amount'] > dl_site_ts_order_clean['mean_1']+dl_site_ts_order_clean['std_1']),'real_pay_amount'] = dl_site_ts_order_clean['mean_1']+dl_site_ts_order_clean['std_1']

# %%
## 剔除极大或者极小的峰值
dl_site_ts_order_clean_count = dl_site_ts_order_clean[['model_code','license_time_year','real_pay_amount']].\
groupby(['model_code','license_time_year']).count().reset_index().rename(columns={'real_pay_amount':'count_2'})

dl_site_ts_order_clean_mean = dl_site_ts_order_clean[['model_code','license_time_year','real_pay_amount']].\
groupby(['model_code','license_time_year']).mean().reset_index().rename(columns={'real_pay_amount':'mean_2'})

dl_site_ts_order_clean_std = dl_site_ts_order_clean[['model_code','license_time_year','real_pay_amount']].\
groupby(['model_code','license_time_year']).std().reset_index().rename(columns={'real_pay_amount':'std_2'})

dl_site_ts_order_clean_median = dl_site_ts_order_clean[['model_code','license_time_year','real_pay_amount']].\
groupby(['model_code','license_time_year']).median().reset_index().rename(columns={'real_pay_amount':'median_2'})

dl_site_ts_order_clean_min = dl_site_ts_order_clean[['model_code','license_time_year','real_pay_amount']].\
groupby(['model_code','license_time_year']).min().reset_index().rename(columns={'real_pay_amount':'min_price_2'})

dl_site_ts_order_clean_max = dl_site_ts_order_clean[['model_code','license_time_year','real_pay_amount']].\
groupby(['model_code','license_time_year']).max().reset_index().rename(columns={'real_pay_amount':'max_price_2'})

dl_site_ts_order_clean = pd.merge(dl_site_ts_order_clean,dl_site_ts_order_clean_count,on=['model_code','license_time_year'],how='left')
dl_site_ts_order_clean = pd.merge(dl_site_ts_order_clean,dl_site_ts_order_clean_mean,on=['model_code','license_time_year'],how='left')
dl_site_ts_order_clean = pd.merge(dl_site_ts_order_clean,dl_site_ts_order_clean_std,on=['model_code','license_time_year'],how='left')
dl_site_ts_order_clean = pd.merge(dl_site_ts_order_clean,dl_site_ts_order_clean_min,on=['model_code','license_time_year'],how='left')
dl_site_ts_order_clean = pd.merge(dl_site_ts_order_clean,dl_site_ts_order_clean_max,on=['model_code','license_time_year'],how='left')
dl_site_ts_order_clean = pd.merge(dl_site_ts_order_clean,dl_site_ts_order_clean_median,on=['model_code','license_time_year'],how='left')

## 剔除峰值
dl_site_ts_order_clean.loc[dl_site_ts_order_clean['mean_2']*0.3 < dl_site_ts_order_clean['std_2'],'std_2'] = dl_site_ts_order_clean['mean_2']*0.3

dl_site_ts_order_clean.loc[(dl_site_ts_order_clean['median_2'] > dl_site_ts_order_clean['mean_2']) & 
#                           (dl_site_ts_order_clean['mean']*0.5 <= dl_site_ts_order_clean['std']) & 
                          (dl_site_ts_order_clean['real_pay_amount'] < dl_site_ts_order_clean['mean_2']-dl_site_ts_order_clean['std_2']),'delete_flag_2'] = 1

dl_site_ts_order_clean.loc[(dl_site_ts_order_clean['median_2'] < dl_site_ts_order_clean['mean_2']) & 
#                           (dl_site_ts_order_clean['mean']*0.5 <= dl_site_ts_order_clean['std']) & 
                          (dl_site_ts_order_clean['real_pay_amount'] > dl_site_ts_order_clean['mean_2']+dl_site_ts_order_clean['std_2']),'delete_flag_2'] = 1

dl_site_ts_order_clean.loc[(dl_site_ts_order_clean['median_2'] > dl_site_ts_order_clean['mean_2']) & 
#                           (dl_site_ts_order_clean['mean']*0.5 <= dl_site_ts_order_clean['std']) & 
                          (dl_site_ts_order_clean['real_pay_amount'] < dl_site_ts_order_clean['mean_2']-dl_site_ts_order_clean['std_2']),'real_pay_amount'] = dl_site_ts_order_clean['mean_2']-dl_site_ts_order_clean['std_2']

dl_site_ts_order_clean.loc[(dl_site_ts_order_clean['median_2'] < dl_site_ts_order_clean['mean_2']) & 
#                           (dl_site_ts_order_clean['mean']*0.5 <= dl_site_ts_order_clean['std']) & 
                          (dl_site_ts_order_clean['real_pay_amount'] > dl_site_ts_order_clean['mean_2']+dl_site_ts_order_clean['std_2']),'real_pay_amount'] = dl_site_ts_order_clean['mean_2']+dl_site_ts_order_clean['std_2']

# %%
## 保存数据
dl_site_ts_order_clean[['car_id','real_pay_amount','delete_flag','delete_flag_1','delete_flag_2']].to_csv(curr_dir+"dl_site_ts_order_clean_"+computer_year+"_yh01.csv")

# %%
print(dl_site_ts_order_clean.loc[(dl_site_ts_order_clean['delete_flag'] == 1)].shape)
print(dl_site_ts_order_clean.loc[(dl_site_ts_order_clean['delete_flag_1'] == 1)].shape)
print(dl_site_ts_order_clean.loc[(dl_site_ts_order_clean['delete_flag_2'] == 1)].shape)
# Out:
# (354968, 32)
# (454127, 32)
# (541769, 32)
